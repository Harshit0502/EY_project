# %%
from firebase_admin import credentials, initialize_app, firestore

# Initialize Firebase
try:
    cred = credentials.Certificate("/content/sample_data/resources/ey-hackathon-ffe58-firebase-adminsdk-gk8uv-dbb395bd43.json")
    initialize_app(cred)
    print("Firebase initialized successfully.")
except Exception as e:
    print(f"Error initializing Firebase: {e}")

# Connect to Firestore
try:
    db = firestore.client()
    print("Connected to Firestore.")
except Exception as e:
    print(f"Error connecting to Firestore: {e}")

# Fetch Users Data
def fetch_users():
    try:
        users_ref = db.collection("users")
        docs = users_ref.stream()
        users = []
        for doc in docs:
            user_data = doc.to_dict()
            user_data["id"] = doc.id  # Add Firestore document ID for reference
            users.append(user_data)
        print(f"Fetched {len(users)} user profiles.")
        return users
    except Exception as e:
        print(f"Error fetching users: {e}")
        return []

# Fetch Schemes Data
def fetch_schemes():
    try:
        schemes_ref = db.collection("gov_schemes")
        docs = schemes_ref.stream()
        schemes = []
        for doc in docs:
            scheme_data = doc.to_dict()
            scheme_data["id"] = doc.id  # Add Firestore document ID for reference
            schemes.append(scheme_data)
        print(f"Fetched {len(schemes)} schemes.")
        return schemes
    except Exception as e:
        print(f"Error fetching schemes: {e}")
        return []

# Fetch and display data
users_data = fetch_users()
schemes_data = fetch_schemes()

print(f"Number of Users Fetched: {len(users_data)}")
print(f"Number of Schemes Fetched: {len(schemes_data)}")
# Out:
# Firebase initialized successfully.
# Connected to Firestore.
# Fetched 10000 user profiles.
# Fetched 9 schemes.
# Number of Users Fetched: 10000
# Number of Schemes Fetched: 9

# %%
def preprocess_users(users_data):
    """Preprocess user profiles to ensure required fields are present."""
    valid_users = []
    for user in users_data:
        if all(key in user for key in ["Age", "Income", "Occupation"]):
            if isinstance(user["Age"], (int, float)) and user["Age"] >= 0:
                valid_users.append(user)
            else:
                print(f"Invalid age in user: {user}")
        else:
            print(f"Missing fields in user: {user}")
    print(f"Preprocessed {len(valid_users)} valid user profiles.")
    return valid_users


def preprocess_schemes(schemes_data):
    """Preprocess scheme data to ensure required fields are present and parse eligibility."""
    valid_schemes = []
    for scheme in schemes_data:
        if all(key in scheme for key in ["Age Range", "Eligibility", "Scheme Name"]):
            try:
                # Parse Eligibility from JSON-like structure if needed
                scheme["Eligibility"] = eval(scheme["Eligibility"]) if isinstance(scheme["Eligibility"], str) else scheme["Eligibility"]
                valid_schemes.append(scheme)
            except Exception as e:
                print(f"Error parsing eligibility in scheme: {scheme}, Error: {e}")
        else:
            print(f"Missing fields in scheme: {scheme}")
    print(f"Preprocessed {len(valid_schemes)} valid schemes.")
    return valid_schemes


# Preprocess data
preprocessed_users = preprocess_users(users_data)
preprocessed_schemes = preprocess_schemes(schemes_data)

# Display counts for verification
print(f"Valid Users: {len(preprocessed_users)}")
print(f"Valid Schemes: {len(preprocessed_schemes)}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Missing fields in user: {'age': 29, 'Occupation': 'Worker', 'Name': 'User_7177', 'income': 9357, 'Location': 'Bangalore', 'id': 'VCXaEnLvDKSL2I3YmiOF'}
# Missing fields in user: {'age': 88, 'Occupation': 'Unemployed', 'Name': 'User_9856', 'income': 9698, 'Location': 'Bangalore', 'id': 'VD9oZdGJEEIPtBYTeo0f'}
# Missing fields in user: {'age': 70, 'Occupation': 'Retired', 'Name': 'User_1580', 'income': 3173, 'Location': 'Bangalore', 'id': 'VDGZFwaUOokcfKV8oVXI'}
# Missing fields in user: {'age': 100, 'Occupation': 'Unemployed', 'Name': 'User_8558', 'income': 3858, 'Location': 'Delhi', 'id': 'VDNyKhbD7j9O5ZQGn85v'}
# Missing fields in user: {'age': 18, 'Occupation': 'Unemployed', 'Name': 'User_1841', 'income': 7718, 'Location': 'Delhi', 'id': 'VDSOnzRzvrZqXKaWC4v4'}
# Missing fields in user: {'age': 77, 'Occupation': 'Worker', 'Name': 'User_76', 'income': 9898, 'Location': 'Delhi', 'id': 'VDUpqcAQZCXxYGcWiYFj'}
# Missing fields in user: {'age': 8, 'Occupation': 'Retired', 'Name': 'User_7532', 'income': 4619, 'Location': 'Mumbai', 'id': 'VDZZn5JuBKs1Nbg9xiE6'}
# Missing fields in user: {'age': 23, 'Occupation': 'Retired', 'Name': 'User_9210', 'income': 7594, 'Location': 'Kolkata', 'id': 'VENEAtFcRAReCV2hl8pO'}
# Missing fields in user: {'age': 88, 'Occupation': 'Unemployed', 'Name': 'User_7733', 'income': 1363, 'Location': 'Delhi', 'id': 'VEwK0ClefcjwAsZgukPH'}
# Missing fields in user: {'age': 90, 'Occupation': 'Worker', 'Name': 'User_2962', 'income': 2823, 'Location': 'Chennai', 'id': 'VFfurvEmexMNNdSVzDYL'}
# Missing fields in user: {'age': 47, 'Occupation': 'Retired', 'Name': 'User_6872', 'income': 7353, 'Location': 'Kolkata', 'id': 'VGaoezNrVQNbY4kvbehI'}
# Missing fields in user: {'age': 28, 'Occupation': 'Unemployed', 'Name': 'User_8328', 'income': 5441, 'Location': 'Delhi', 'id': 'VHJtic365mSkhzeKVRs2'}
# Missing fields in user: {'age': 78, 'Occupation': 'Student', 'Name': 'User_5457', 'income': 4408, 'Location': 'Kolkata', 'id': 'VHOpauNxSbYspld9vYq7'}
# Missing fields in user: {'age': 62, 'Occupation': 'Retired', 'Name': 'User_7956', 'income': 7646, 'Location': 'Mumbai', 'id': 'VHig9v8G6OXhG4XLLPax'}
# Missing fields in user: {'age': 87, 'Occupation': 'Student', 'Name': 'User_951', 'income': 7829, 'Location': 'Kolkata', 'id': 'VHnYMAQORkV1TNIlFDAH'}
# Missing fields in user: {'age': 52, 'Occupation': 'Retired', 'Name': 'User_5418', 'income': 4996, 'Location': 'Chennai', 'id': 'VIj9lL9xIf442QSQS2JE'}
# Missing fields in user: {'age': 91, 'Occupation': 'Worker', 'Name': 'User_7529', 'income': 238, 'Location': 'Delhi', 'id': 'VIrBx7zzrjz1jLGbDedN'}
# Missing fields in user: {'age': 63, 'Occupation': 'Worker', 'Name': 'User_2717', 'income': 3456, 'Location': 'Chennai', 'id': 'VJDF6e8hZAzWrP08GuKD'}
# Missing fields in user: {'age': 30, 'Occupation': 'Unemployed', 'Name': 'User_8016', 'income': 70, 'Location': 'Chennai', 'id': 'VJrwaI64Mwx5Sk4BDyzq'}
# Missing fields in user: {'age': 73, 'Occupation': 'Worker', 'Name': 'User_7961', 'income': 5360, 'Location': 'Mumbai', 'id': 'VL0mZOX3tzJLIWH6Tej3'}
# Missing fields in user: {'age': 33, 'Occupation': 'Retired', 'Name': 'User_2048', 'income': 9083, 'Location': 'Bangalore', 'id': 'VLoZO0RJFVlfb5iOBbSW'}
# Missing fields in user: {'age': 77, 'Occupation': 'Retired', 'Name': 'User_244', 'income': 1047, 'Location': 'Bangalore', 'id': 'VMItKGhgELHX0HeqSypR'}
# Missing fields in user: {'age': 56, 'Occupation': 'Student', 'Name': 'User_3383', 'income': 403, 'Location': 'Mumbai', 'id': 'VMWhi5gBnEa5ybqi2uw8'}
# Missing fields in user: {'age': 48, 'Occupation': 'Unemployed', 'Name': 'User_3643', 'income': 1366, 'Location': 'Kolkata', 'id': 'VMfOl3z7HG3UllbWZ9h6'}
# Missing fields in user: {'age': 8, 'Occupation': 'Retired', 'Name': 'User_2620', 'income': 4686, 'Location': 'Chennai', 'id': 'VMsbtObrM3Eac6JaZ9TS'}
# Missing fields in user: {'age': 40, 'Occupation': 'Retired', 'Name': 'User_8606', 'income': 9913, 'Location': 'Bangalore', 'id': 'VN504HztayCukAYhJv9e'}
# Missing fields in user: {'age': 44, 'Occupation': 'Retired', 'Name': 'User_9883', 'income': 1754, 'Location': 'Kolkata', 'id': 'VNRFiBbuOoYpkHW09wuP'}
# Missing fields in user: {'age': 62, 'Occupation': 'Student', 'Name': 'User_1963', 'income': 6740, 'Location': 'Delhi', 'id': 'VNw0tjpIpY2py1DaYFJa'}
# Missing fields in user: {'age': 12, 'Occupation': 'Student', 'Name': 'User_9445', 'income': 2404, 'Location': 'Chennai', 'id': 'VO3D8QxRxJ9aS4GKEpwe'}
# Missing fields in user: {'age': 59, 'Occupation': 'Unemployed', 'Name': 'User_3255', 'income': 6126, 'Location': 'Chennai', 'id': 'VOlHrndHQymLqwHQUVva'}
# Missing fields in user: {'age': 14, 'Occupation': 'Retired', 'Name': 'User_5116', 'income': 8865, 'Location': 'Bangalore', 'id': 'VPE24VEzpmvkQkEEuoUV'}
# Missing fields in user: {'age': 56, 'Occupation': 'Unemployed', 'Name': 'User_3936', 'income': 9814, 'Location': 'Mumbai', 'id': 'VPMdW2l46i89TNmP3gbJ'}
# Missing fields in user: {'age': 97, 'Occupation': 'Retired', 'Name': 'User_29', 'income': 9552, 'Location': 'Kolkata', 'id': 'VPlCBLjQIsRPoOcUoQOk'}
# Missing fields in user: {'age': 74, 'Occupation': 'Retired', 'Name': 'User_387', 'income': 7399, 'Location': 'Chennai', 'id': 'VQMprmyNwYrpfvCgnbnx'}
# Missing fields in user: {'age': 88, 'Occupation': 'Unemployed', 'Name': 'User_6847', 'income': 3520, 'Location': 'Kolkata', 'id': 'VR9sqDQr4z4TEkURKK4Y'}
# Missing fields in user: {'age': 90, 'Occupation': 'Unemployed', 'Name': 'User_9073', 'income': 6192, 'Location': 'Mumbai', 'id': 'VSm1Z25NG5LVdc4r7wFE'}
# Missing fields in user: {'age': 60, 'Occupation': 'Worker', 'Name': 'User_1114', 'income': 2063, 'Location': 'Kolkata', 'id': 'VSrN0f8tomLoayNvcEfn'}
# Missing fields in user: {'age': 72, 'Occupation': 'Unemployed', 'Name': 'User_4146', 'income': 2621, 'Location': 'Mumbai', 'id': 'VTL8G8u4OrNADtfLZdYt'}
# Missing fields in user: {'age': 58, 'Occupation': 'Retired', 'Name': 'User_5506', 'income': 2272, 'Location': 'Chennai', 'id': 'VTVFH8xzaxTcGc2UhWBn'}
# Missing fields in user: {'age': 44, 'Occupation': 'Retired', 'Name': 'User_3799', 'income': 9274, 'Location': 'Delhi', 'id': 'VU03m1ckEPvPkDHHtUXH'}
# Missing fields in user: {'age': 12, 'Occupation': 'Student', 'Name': 'User_8890', 'income': 4003, 'Location': 'Bangalore', 'id': 'VUCpsCxMOxTdwjWbBYFf'}
# Missing fields in user: {'age': 26, 'Occupation': 'Student', 'Name': 'User_6100', 'income': 3277, 'Location': 'Delhi', 'id': 'VULhYhfzPd7PMf6TKp08'}
# Missing fields in user: {'age': 47, 'Occupation': 'Worker', 'Name': 'User_5705', 'income': 5181, 'Location': 'Kolkata', 'id': 'VUZN9o1Zimx6c8d4dAP1'}
# Missing fields in user: {'age': 33, 'Occupation': 'Worker', 'Name': 'User_6385', 'income': 4558, 'Location': 'Bangalore', 'id': 'VUf7Nf9TthRMkbsKXGiO'}
# Missing fields in user: {'age': 83, 'Occupation': 'Worker', 'Name': 'User_166', 'income': 4975, 'Location': 'Delhi', 'id': 'VVM2nGrQQMtFnw4ctqoI'}
# Missing fields in user: {'age': 97, 'Occupation': 'Student', 'Name': 'User_2914', 'income': 397, 'Location': 'Delhi', 'id': 'VVZJc8OE0q7ZjAmj7C2d'}
# Missing fields in user: {'age': 1, 'Occupation': 'Unemployed', 'Name': 'User_5187', 'income': 6226, 'Location': 'Kolkata', 'id': 'VViqTjwy8CDkc1JHUbJm'}
# Missing fields in user: {'age': 5, 'Occupation': 'Unemployed', 'Name': 'User_7782', 'income': 3407, 'Location': 'Bangalore', 'id': 'VW7iJs0t8iSSaXvhUoDV'}
# Missing fields in user: {'age': 52, 'Occupation': 'Worker', 'Name': 'User_3708', 'income': 9247, 'Location': 'Mumbai', 'id': 'VWcaX96SZboPcZyjwylS'}
# Missing fields in user: {'age': 85, 'Occupation': 'Student', 'Name': 'User_3497', 'income': 2154, 'Location': 'Bangalore', 'id': 'VWeMhET6b0Cq0KkEFP7v'}
# Missing fields in user: {'age': 69, 'Occupation': 'Student', 'Name': 'User_6970', 'income': 5451, 'Location': 'Bangalore', 'id': 'VWybPSFkQLEyLDhywKCP'}
# Missing fields in user: {'age': 30, 'Occupation': 'Student', 'Name': 'User_7350', 'income': 436, 'Location': 'Chennai', 'id': 'VXij0gCCTRvuO1eJY7X8'}
# Missing fields in user: {'age': 64, 'Occupation': 'Student', 'Name': 'User_4676', 'income': 2783, 'Location': 'Bangalore', 'id': 'VXnzPa50SlCay3fTkSEH'}
# Missing fields in user: {'age': 71, 'Occupation': 'Retired', 'Name': 'User_9608', 'income': 5941, 'Location': 'Delhi', 'id': 'VY5TIPiPaCTMFxEdUII1'}
# Missing fields in user: {'age': 73, 'Occupation': 'Retired', 'Name': 'User_9673', 'income': 7549, 'Location': 'Bangalore', 'id': 'VYZdhEb9gUj1wIE00vOt'}
# Missing fields in user: {'age': 84, 'Occupation': 'Retired', 'Name': 'User_4203', 'income': 9190, 'Location': 'Delhi', 'id': 'VZIDFocARCsW6KHXAWKH'}
# Missing fields in user: {'age': 91, 'Occupation': 'Worker', 'Name': 'User_598', 'income': 6170, 'Location': 'Bangalore', 'id': 'VaAe2wafUlp4O8mJuCNf'}
# Missing fields in user: {'age': 74, 'Occupation': 'Worker', 'Name': 'User_5758', 'income': 2235, 'Location': 'Delhi', 'id': 'VaSyjccHgaSRjwGF4Go9'}
# Missing fields in user: {'age': 84, 'Occupation': 'Student', 'Name': 'User_6156', 'income': 4796, 'Location': 'Mumbai', 'id': 'Var3nb2Hkr3EFOYQs8C1'}
# Missing fields in user: {'age': 1, 'Occupation': 'Unemployed', 'Name': 'User_7885', 'income': 5100, 'Location': 'Bangalore', 'id': 'Vb2J7k5RTJ0Gu2nFofen'}
# Missing fields in user: {'age': 36, 'Occupation': 'Student', 'Name': 'User_8048', 'income': 3651, 'Location': 'Delhi', 'id': 'Vb5xw6vo3FwkmokCIPMa'}
# Missing fields in user: {'age': 47, 'Occupation': 'Student', 'Name': 'User_9792', 'income': 6221, 'Location': 'Kolkata', 'id': 'Vb768Xzo5XQtP6gH3v9m'}
# Missing fields in user: {'age': 21, 'Occupation': 'Worker', 'Name': 'User_935', 'income': 1213, 'Location': 'Delhi', 'id': 'VbMU131JRJSCnzF6AU3O'}
# Missing fields in user: {'age': 44, 'Occupation': 'Unemployed', 'Name': 'User_8822', 'income': 8714, 'Location': 'Delhi', 'id': 'VbRCdBOcmXgn5LCvJEI2'}
# Missing fields in user: {'age': 94, 'Occupation': 'Unemployed', 'Name': 'User_5473', 'income': 8944, 'Location': 'Bangalore', 'id': 'VbwNyQMC60FJF3O3z1t6'}
# Missing fields in user: {'age': 92, 'Occupation': 'Student', 'Name': 'User_8047', 'income': 7690, 'Location': 'Delhi', 'id': 'VcLhXnJVZ0fLsshzMMm4'}
# Missing fields in user: {'age': 9, 'Occupation': 'Unemployed', 'Name': 'User_8496', 'income': 7401, 'Location': 'Chennai', 'id': 'VcfoJUPA9AiivQr2Qe0L'}
# Missing fields in user: {'age': 94, 'Occupation': 'Student', 'Name': 'User_8007', 'income': 260, 'Location': 'Bangalore', 'id': 'VcwC0nAvWvPCXd4rZG8J'}
# Missing fields in user: {'age': 7, 'Occupation': 'Worker', 'Name': 'User_5501', 'income': 9881, 'Location': 'Bangalore', 'id': 'Vd8LP1X3wl5CGs6cKjGu'}
# Missing fields in user: {'age': 79, 'Occupation': 'Worker', 'Name': 'User_5130', 'income': 3641, 'Location': 'Mumbai', 'id': 'VdWA6RY539B9ITYSIFdW'}
# Missing fields in user: {'age': 34, 'Occupation': 'Retired', 'Name': 'User_2709', 'income': 8848, 'Location': 'Mumbai', 'id': 'VdiJevdA00r6rxpbYefc'}
# Missing fields in user: {'age': 40, 'Occupation': 'Retired', 'Name': 'User_6953', 'income': 539, 'Location': 'Kolkata', 'id': 'Vdp13rul6B5GYTwE3rn8'}
# Missing fields in user: {'age': 80, 'Occupation': 'Retired', 'Name': 'User_459', 'income': 1142, 'Location': 'Mumbai', 'id': 'Vds4qhuh5VX2MoAYIc7G'}
# Missing fields in user: {'age': 62, 'Occupation': 'Worker', 'Name': 'User_1758', 'income': 6002, 'Location': 'Chennai', 'id': 'Vdt5vCgzftVPSqvwaLtI'}
# Missing fields in user: {'age': 66, 'Occupation': 'Unemployed', 'Name': 'User_2378', 'income': 4090, 'Location': 'Delhi', 'id': 'VeyR70MUBBC5sUbsdoEr'}
# Missing fields in user: {'age': 20, 'Occupation': 'Student', 'Name': 'User_8298', 'income': 255, 'Location': 'Chennai', 'id': 'VfK9IlQX5jhjo6IRWRCY'}
# Missing fields in user: {'age': 91, 'Occupation': 'Student', 'Name': 'User_2168', 'income': 3520, 'Location': 'Delhi', 'id': 'Vfa2vbQO5TWxuBsG6qn2'}
# Missing fields in user: {'age': 45, 'Occupation': 'Unemployed', 'Name': 'User_6202', 'income': 5713, 'Location': 'Bangalore', 'id': 'Vfc8hqXBb7BvIEfD123e'}
# Missing fields in user: {'age': 92, 'Occupation': 'Retired', 'Name': 'User_9472', 'income': 2055, 'Location': 'Bangalore', 'id': 'VfkGbit3enl3ohI4f8QX'}
# Missing fields in user: {'age': 9, 'Occupation': 'Unemployed', 'Name': 'User_4607', 'income': 7143, 'Location': 'Chennai', 'id': 'VfnaZGpCVj6pggcI2NQd'}
# Missing fields in user: {'age': 47, 'Occupation': 'Worker', 'Name': 'User_1028', 'income': 4378, 'Location': 'Kolkata', 'id': 'VfujSyNk5kYikNeVmmKs'}
# Missing fields in user: {'age': 54, 'Occupation': 'Worker', 'Name': 'User_6481', 'income': 4792, 'Location': 'Kolkata', 'id': 'Vgz7D3hVPHglnGRt4Cep'}
# Missing fields in user: {'age': 57, 'Occupation': 'Student', 'Name': 'User_7731', 'income': 538, 'Location': 'Delhi', 'id': 'VhDlScEyzkgS8yAZ73y6'}
# Missing fields in user: {'age': 28, 'Occupation': 'Unemployed', 'Name': 'User_1067', 'income': 8040, 'Location': 'Delhi', 'id': 'Vhf7hLKjIVc8A2RJ6VwE'}
# Missing fields in user: {'age': 60, 'Occupation': 'Student', 'Name': 'User_4900', 'income': 4459, 'Location': 'Bangalore', 'id': 'VhjevVbbwwl7AkSgemzs'}
# Missing fields in user: {'age': 96, 'Occupation': 'Worker', 'Name': 'User_2888', 'income': 95, 'Location': 'Delhi', 'id': 'VhmJt1OCTiJTrcMQvnAv'}
# Missing fields in user: {'age': 73, 'Occupation': 'Student', 'Name': 'User_6865', 'income': 971, 'Location': 'Delhi', 'id': 'ViNxASHJID7vA8f9q8VQ'}
# Missing fields in user: {'age': 80, 'Occupation': 'Retired', 'Name': 'User_7813', 'income': 2839, 'Location': 'Bangalore', 'id': 'ViygWtCD5VWtAp3SoYco'}
# Missing fields in user: {'age': 44, 'Occupation': 'Unemployed', 'Name': 'User_4672', 'income': 4213, 'Location': 'Chennai', 'id': 'VkNxFoqNFLLeuDt86BCh'}
# Missing fields in user: {'age': 10, 'Occupation': 'Worker', 'Name': 'User_5379', 'income': 5857, 'Location': 'Bangalore', 'id': 'VkOHMDlaOCj8Ceqvov1F'}
# Missing fields in user: {'age': 41, 'Occupation': 'Worker', 'Name': 'User_2412', 'income': 7132, 'Location': 'Kolkata', 'id': 'VlY3LfsFAF7ib7dwL4j9'}
# Missing fields in user: {'age': 81, 'Occupation': 'Student', 'Name': 'User_8389', 'income': 9108, 'Location': 'Bangalore', 'id': 'Vm9w2Xxs8ougR0CgYP8k'}
# Missing fields in user: {'age': 46, 'Occupation': 'Worker', 'Name': 'User_6332', 'income': 9128, 'Location': 'Delhi', 'id': 'VmvCso3knqWbNjvHp8YR'}
# Missing fields in user: {'age': 73, 'Occupation': 'Student', 'Name': 'User_4080', 'income': 9478, 'Location': 'Kolkata', 'id': 'VnccR6biwZvzAtQlV3Ma'}
# Missing fields in user: {'age': 88, 'Occupation': 'Worker', 'Name': 'User_9224', 'income': 1504, 'Location': 'Mumbai', 'id': 'Vne469mRtM6u74jV1RCW'}
# Missing fields in user: {'age': 68, 'Occupation': 'Worker', 'Name': 'User_1819', 'income': 3690, 'Location': 'Bangalore', 'id': 'VnyX5gmcHpZfGY1OytVh'}
# Missing fields in user: {'age': 52, 'Occupation': 'Worker', 'Name': 'User_8624', 'income': 342, 'Location': 'Mumbai', 'id': 'VoC6UOw8sIvuN3NrAMXH'}
# Missing fields in user: {'age': 7, 'Occupation': 'Student', 'Name': 'User_9723', 'income': 6280, 'Location': 'Chennai', 'id': 'VooCnIoCdzbZB9FQdLEC'}
# Missing fields in user: {'age': 93, 'Occupation': 'Worker', 'Name': 'User_3183', 'income': 3363, 'Location': 'Mumbai', 'id': 'VoygFMQObC376NWGlSe3'}
# Missing fields in user: {'age': 10, 'Occupation': 'Unemployed', 'Name': 'User_910', 'income': 161, 'Location': 'Mumbai', 'id': 'VptgbCEcpQAuHGQB6fBX'}
# Missing fields in user: {'age': 39, 'Occupation': 'Retired', 'Name': 'User_6023', 'income': 3733, 'Location': 'Kolkata', 'id': 'VqJjWr3j8gJp6iq2XaEi'}
# Missing fields in user: {'age': 56, 'Occupation': 'Worker', 'Name': 'User_2225', 'income': 7903, 'Location': 'Mumbai', 'id': 'VrAaKPSGK76vFVS0nVAP'}
# Missing fields in user: {'age': 4, 'Occupation': 'Unemployed', 'Name': 'User_7568', 'income': 7433, 'Location': 'Bangalore', 'id': 'VrK5v5Y87mTHZVHzrofN'}
# Missing fields in user: {'age': 18, 'Occupation': 'Unemployed', 'Name': 'User_6622', 'income': 1322, 'Location': 'Bangalore', 'id': 'VraAaBIUicxppVqmzoqM'}
# Missing fields in user: {'age': 18, 'Occupation': 'Unemployed', 'Name': 'User_6002', 'income': 8808, 'Location': 'Bangalore', 'id': 'VrxAnDMWPzMvmyPc76oj'}
# Missing fields in user: {'age': 17, 'Occupation': 'Student', 'Name': 'User_1507', 'income': 8130, 'Location': 'Chennai', 'id': 'VsLusztrWIw2MwRLL81J'}
# Missing fields in user: {'age': 58, 'Occupation': 'Retired', 'Name': 'User_7967', 'income': 9088, 'Location': 'Delhi', 'id': 'VsdiIGji29n2fPmRdu2F'}
# Missing fields in user: {'age': 85, 'Occupation': 'Retired', 'Name': 'User_1787', 'income': 5434, 'Location': 'Chennai', 'id': 'VtEFMGnrazT6DdrnNdbO'}
# Missing fields in user: {'age': 86, 'Occupation': 'Unemployed', 'Name': 'User_1584', 'income': 7033, 'Location': 'Delhi', 'id': 'Vtn7R3UAZrhc9TiTLKbG'}
# Missing fields in user: {'age': 13, 'Occupation': 'Worker', 'Name': 'User_8690', 'income': 160, 'Location': 'Kolkata', 'id': 'Vtoa9EzGNB5nys3TFNdW'}
# Missing fields in user: {'age': 27, 'Occupation': 'Worker', 'Name': 'User_5497', 'income': 9867, 'Location': 'Bangalore', 'id': 'VtrLLb4CdD0q5cbA3x4E'}
# Missing fields in user: {'age': 2, 'Occupation': 'Student', 'Name': 'User_1415', 'income': 8744, 'Location': 'Bangalore', 'id': 'Vtu9M1R7YFd0Ougc8HBo'}
# Missing fields in user: {'age': 92, 'Occupation': 'Retired', 'Name': 'User_559', 'income': 57, 'Location': 'Delhi', 'id': 'VuOVq9LDS2CzsxwZsfsH'}
# Missing fields in user: {'age': 80, 'Occupation': 'Student', 'Name': 'User_7812', 'income': 2484, 'Location': 'Mumbai', 'id': 'VuSG7QvSWe38mVUW3ef1'}
# Missing fields in user: {'age': 83, 'Occupation': 'Unemployed', 'Name': 'User_3077', 'income': 126, 'Location': 'Chennai', 'id': 'VuzAe7KQkqGxADv9s7Bx'}
# Missing fields in user: {'age': 90, 'Occupation': 'Worker', 'Name': 'User_23', 'income': 2317, 'Location': 'Delhi', 'id': 'Vvt9dGl6G7XfMzo1qW8A'}
# Missing fields in user: {'age': 26, 'Occupation': 'Retired', 'Name': 'User_3039', 'income': 7711, 'Location': 'Delhi', 'id': 'VwCnN143n79XOSEsb3XE'}
# Missing fields in user: {'age': 34, 'Occupation': 'Retired', 'Name': 'User_5415', 'income': 9017, 'Location': 'Mumbai', 'id': 'VwXW3KgF6uy3XQIfMf6h'}
# Missing fields in user: {'age': 72, 'Occupation': 'Unemployed', 'Name': 'User_615', 'income': 1447, 'Location': 'Bangalore', 'id': 'VwkiwPAig2Upnqf499tN'}
# Missing fields in user: {'age': 84, 'Occupation': 'Unemployed', 'Name': 'User_1092', 'income': 7877, 'Location': 'Chennai', 'id': 'Vx1ghnSidYnYZzoLMhpC'}
# Missing fields in user: {'age': 69, 'Occupation': 'Retired', 'Name': 'User_4824', 'income': 9927, 'Location': 'Kolkata', 'id': 'VxkJtVV5ynoRdlEer0cp'}
# Missing fields in user: {'age': 66, 'Occupation': 'Retired', 'Name': 'User_4202', 'income': 221, 'Location': 'Chennai', 'id': 'VyUjlfn3TrAxdBH2ElNG'}
# Missing fields in user: {'age': 63, 'Occupation': 'Retired', 'Name': 'User_1394', 'income': 7441, 'Location': 'Bangalore', 'id': 'Vyc0q5pVlaUCD2X2GlXe'}
# Missing fields in user: {'age': 12, 'Occupation': 'Retired', 'Name': 'User_9681', 'income': 5257, 'Location': 'Delhi', 'id': 'VyfvyUMSXnR6oM7gncPD'}
# Missing fields in user: {'age': 85, 'Occupation': 'Retired', 'Name': 'User_6526', 'income': 9861, 'Location': 'Mumbai', 'id': 'VyjMY9w05CoMdl3Ow2C3'}
# Missing fields in user: {'age': 60, 'Occupation': 'Retired', 'Name': 'User_3488', 'income': 9039, 'Location': 'Delhi', 'id': 'Vz2QP93TqsGud3kqObJ3'}
# Missing fields in user: {'age': 28, 'Occupation': 'Unemployed', 'Name': 'User_686', 'income': 6453, 'Location': 'Mumbai', 'id': 'VzAmewPQJgg1FjdAQQoX'}
# Missing fields in user: {'age': 17, 'Occupation': 'Worker', 'Name': 'User_9130', 'income': 7311, 'Location': 'Mumbai', 'id': 'VzNmAVufKJKbZQHJekLG'}
# Missing fields in user: {'age': 73, 'Occupation': 'Unemployed', 'Name': 'User_9923', 'income': 2717, 'Location': 'Delhi', 'id': 'VzVJhRE1uU2yx21UoWMm'}
# Missing fields in user: {'age': 36, 'Occupation': 'Unemployed', 'Name': 'User_4859', 'income': 7374, 'Location': 'Bangalore', 'id': 'W0MITRJErPnyqquNW2ue'}
# Missing fields in user: {'age': 39, 'Occupation': 'Unemployed', 'Name': 'User_3720', 'income': 5279, 'Location': 'Bangalore', 'id': 'W0Ysji5IGVX2Wp4p9AyC'}
# Missing fields in user: {'age': 85, 'Occupation': 'Student', 'Name': 'User_9172', 'income': 2611, 'Location': 'Bangalore', 'id': 'W13zFZloBw2HVMmTrsar'}
# Missing fields in user: {'age': 28, 'Occupation': 'Worker', 'Name': 'User_9192', 'income': 8838, 'Location': 'Kolkata', 'id': 'W1GbSZx1FrFjseAdzIbx'}
# Missing fields in user: {'age': 75, 'Occupation': 'Student', 'Name': 'User_3010', 'income': 579, 'Location': 'Kolkata', 'id': 'W1rfI4s5dK3eP3Pf3Wrb'}
# Missing fields in user: {'age': 62, 'Occupation': 'Worker', 'Name': 'User_2009', 'income': 208, 'Location': 'Chennai', 'id': 'W2TtHjYdZpxDoN5JmmZj'}
# Missing fields in user: {'age': 3, 'Occupation': 'Unemployed', 'Name': 'User_8656', 'income': 5470, 'Location': 'Bangalore', 'id': 'W3WRIdxRzou9700pJU3Z'}
# Missing fields in user: {'age': 7, 'Occupation': 'Unemployed', 'Name': 'User_988', 'income': 134, 'Location': 'Bangalore', 'id': 'W3iW6Cjj5IzPtmdyijkD'}
# Missing fields in user: {'age': 30, 'Occupation': 'Student', 'Name': 'User_2294', 'income': 3693, 'Location': 'Mumbai', 'id': 'W3jluPHjNPnyvhIo8LpC'}
# Missing fields in user: {'age': 64, 'Occupation': 'Unemployed', 'Name': 'User_8500', 'income': 4200, 'Location': 'Bangalore', 'id': 'W4xuznkhzf0khUqDfL1G'}
# Missing fields in user: {'age': 57, 'Occupation': 'Unemployed', 'Name': 'User_9145', 'income': 3116, 'Location': 'Delhi', 'id': 'W4yF1YmprhQAzJ603JYW'}
# Missing fields in user: {'age': 65, 'Occupation': 'Student', 'Name': 'User_3268', 'income': 6266, 'Location': 'Chennai', 'id': 'W55Di70wqBlUXUdwCnVv'}
# Missing fields in user: {'age': 2, 'Occupation': 'Student', 'Name': 'User_4832', 'income': 1156, 'Location': 'Mumbai', 'id': 'W5LYHbjvuUcD0YEkq5Dy'}
# Missing fields in user: {'age': 51, 'Occupation': 'Unemployed', 'Name': 'User_8425', 'income': 5360, 'Location': 'Mumbai', 'id': 'W5aPxZtPRFGe2RGEXNIO'}
# Missing fields in user: {'age': 15, 'Occupation': 'Worker', 'Name': 'User_8963', 'income': 2926, 'Location': 'Kolkata', 'id': 'W5bmROhofbFeB3rrBar3'}
# Missing fields in user: {'age': 48, 'Occupation': 'Unemployed', 'Name': 'User_3634', 'income': 7082, 'Location': 'Bangalore', 'id': 'W5i34hYuJwOJh39xdhic'}
# Missing fields in user: {'age': 9, 'Occupation': 'Student', 'Name': 'User_8262', 'income': 7925, 'Location': 'Chennai', 'id': 'W63zKes3oC0iQdKIhN8n'}
# Missing fields in user: {'age': 58, 'Occupation': 'Student', 'Name': 'User_2641', 'income': 7014, 'Location': 'Delhi', 'id': 'W6Bzu83D4opwem0WQead'}
# Missing fields in user: {'age': 97, 'Occupation': 'Retired', 'Name': 'User_9249', 'income': 2071, 'Location': 'Delhi', 'id': 'W6F1YySvtSEAJdSFwxW9'}
# Missing fields in user: {'age': 35, 'Occupation': 'Worker', 'Name': 'User_6021', 'income': 5542, 'Location': 'Bangalore', 'id': 'W6JbfNbrvF9s769LzpwR'}
# Missing fields in user: {'age': 47, 'Occupation': 'Student', 'Name': 'User_2674', 'income': 1762, 'Location': 'Chennai', 'id': 'W6SxT0WRRzQnMmbgFXqo'}
# Missing fields in user: {'age': 66, 'Occupation': 'Worker', 'Name': 'User_2909', 'income': 5221, 'Location': 'Delhi', 'id': 'W7Zkha4QO7W0olbOIUeD'}
# Missing fields in user: {'age': 98, 'Occupation': 'Unemployed', 'Name': 'User_7680', 'income': 732, 'Location': 'Kolkata', 'id': 'W7eGM60ylE6xVBHHillg'}
# Missing fields in user: {'age': 55, 'Occupation': 'Unemployed', 'Name': 'User_6731', 'income': 5427, 'Location': 'Kolkata', 'id': 'W7qEdIw5PI1lUFK4RCTC'}
# Missing fields in user: {'age': 34, 'Occupation': 'Worker', 'Name': 'User_2896', 'income': 6850, 'Location': 'Bangalore', 'id': 'W8AfPifmUeoTQXMooOaK'}
# Missing fields in user: {'age': 73, 'Occupation': 'Unemployed', 'Name': 'User_5939', 'income': 2851, 'Location': 'Bangalore', 'id': 'W8GirCk4k1QvEdVxr17D'}
# Missing fields in user: {'age': 57, 'Occupation': 'Retired', 'Name': 'User_3618', 'income': 1966, 'Location': 'Bangalore', 'id': 'W95kQM5UiyThv7sbqEgT'}
# Missing fields in user: {'age': 38, 'Occupation': 'Worker', 'Name': 'User_5429', 'income': 4298, 'Location': 'Kolkata', 'id': 'W9IDLkAEbB1pXsH0bNwo'}
# Missing fields in user: {'age': 79, 'Occupation': 'Retired', 'Name': 'User_6967', 'income': 5388, 'Location': 'Delhi', 'id': 'W9JqtIat0T2NGFZoyPh5'}
# Missing fields in user: {'age': 79, 'Occupation': 'Retired', 'Name': 'User_5419', 'income': 4686, 'Location': 'Chennai', 'id': 'W9Nv1Yp55Wm7GzHCY1P7'}
# Missing fields in user: {'age': 48, 'Occupation': 'Retired', 'Name': 'User_3301', 'income': 2171, 'Location': 'Delhi', 'id': 'W9yQsWpKaz5F2ToDQ0uU'}
# Missing fields in user: {'age': 65, 'Occupation': 'Student', 'Name': 'User_6445', 'income': 8535, 'Location': 'Bangalore', 'id': 'WA66lRGQqe2UeGH4wpQn'}
# Missing fields in user: {'age': 27, 'Occupation': 'Worker', 'Name': 'User_6324', 'income': 2815, 'Location': 'Chennai', 'id': 'WA9zBdGmtaXmwpf1XO3d'}
# Missing fields in user: {'age': 34, 'Occupation': 'Retired', 'Name': 'User_7333', 'income': 8438, 'Location': 'Delhi', 'id': 'WAHrZrfYEFuhV75tW1XF'}
# Missing fields in user: {'age': 50, 'Occupation': 'Student', 'Name': 'User_7930', 'income': 9800, 'Location': 'Delhi', 'id': 'WAxWuSiu6h2Jsljwz4eN'}
# Missing fields in user: {'age': 59, 'Occupation': 'Student', 'Name': 'User_9859', 'income': 2907, 'Location': 'Kolkata', 'id': 'WBLCMXY0jXwgwyzvZYMl'}
# Missing fields in user: {'age': 72, 'Occupation': 'Student', 'Name': 'User_7507', 'income': 7384, 'Location': 'Bangalore', 'id': 'WBhEoqsXlvNTwyg7h6Gi'}
# Missing fields in user: {'age': 20, 'Occupation': 'Unemployed', 'Name': 'User_8254', 'income': 7124, 'Location': 'Chennai', 'id': 'WC3wz7A2dnlxW013ZMmH'}
# Missing fields in user: {'age': 46, 'Occupation': 'Unemployed', 'Name': 'User_9275', 'income': 5990, 'Location': 'Kolkata', 'id': 'WCrcQe4fSSFA7Rx0LumQ'}
# Missing fields in user: {'age': 41, 'Occupation': 'Retired', 'Name': 'User_5424', 'income': 1211, 'Location': 'Chennai', 'id': 'WD3Lgw0cHZ1x3TqCWjz4'}
# Missing fields in user: {'age': 94, 'Occupation': 'Retired', 'Name': 'User_7990', 'income': 6518, 'Location': 'Mumbai', 'id': 'WDU4pobQSNRuyWcsrqqn'}
# Missing fields in user: {'age': 35, 'Occupation': 'Student', 'Name': 'User_3706', 'income': 7598, 'Location': 'Chennai', 'id': 'WDtDHF5Du0UbYnX922FI'}
# Missing fields in user: {'age': 37, 'Occupation': 'Retired', 'Name': 'User_7952', 'income': 4161, 'Location': 'Bangalore', 'id': 'WE5f56JZkkpUpcceOk14'}
# Missing fields in user: {'age': 58, 'Occupation': 'Retired', 'Name': 'User_539', 'income': 4639, 'Location': 'Mumbai', 'id': 'WEWEHNTUquhFHHrNMKPd'}
# Missing fields in user: {'age': 50, 'Occupation': 'Unemployed', 'Name': 'User_3727', 'income': 8376, 'Location': 'Delhi', 'id': 'WEnKwVjtImV2JcAnIrB9'}
# Missing fields in user: {'age': 49, 'Occupation': 'Retired', 'Name': 'User_7342', 'income': 5819, 'Location': 'Mumbai', 'id': 'WFVfpkvErZt0PEUAKMCX'}
# Missing fields in user: {'age': 20, 'Occupation': 'Worker', 'Name': 'User_6467', 'income': 8649, 'Location': 'Chennai', 'id': 'WFXvrUNnRp948nWAqdEg'}
# Missing fields in user: {'age': 10, 'Occupation': 'Retired', 'Name': 'User_7010', 'income': 9601, 'Location': 'Delhi', 'id': 'WFheJRTqED8HqAYeFLI4'}
# Missing fields in user: {'age': 10, 'Occupation': 'Student', 'Name': 'User_68', 'income': 8197, 'Location': 'Chennai', 'id': 'WFxQqg4u2VHbkJu2SKoL'}
# Missing fields in user: {'age': 61, 'Occupation': 'Unemployed', 'Name': 'User_9997', 'income': 3899, 'Location': 'Bangalore', 'id': 'WGIX261fiGAGmK4DSpkj'}
# Missing fields in user: {'age': 11, 'Occupation': 'Unemployed', 'Name': 'User_5515', 'income': 8765, 'Location': 'Delhi', 'id': 'WGUhuzbSaBgg73KAxlCE'}
# Missing fields in user: {'age': 78, 'Occupation': 'Unemployed', 'Name': 'User_8139', 'income': 829, 'Location': 'Bangalore', 'id': 'WGa9JDgrc3YqgUzd6UzP'}
# Missing fields in user: {'age': 6, 'Occupation': 'Unemployed', 'Name': 'User_2795', 'income': 7377, 'Location': 'Kolkata', 'id': 'WHETCI7wJSpiT9T4NyR9'}
# Missing fields in user: {'age': 71, 'Occupation': 'Worker', 'Name': 'User_396', 'income': 2339, 'Location': 'Delhi', 'id': 'WHd0uHy8lyiRkEUaCG5k'}
# Missing fields in user: {'age': 43, 'Occupation': 'Worker', 'Name': 'User_6846', 'income': 2185, 'Location': 'Kolkata', 'id': 'WI4A59i2KB7vNEuY1UpD'}
# Missing fields in user: {'age': 71, 'Occupation': 'Student', 'Name': 'User_4103', 'income': 5858, 'Location': 'Chennai', 'id': 'WIFzR56ckahc5CHG6Toa'}
# Missing fields in user: {'age': 89, 'Occupation': 'Student', 'Name': 'User_9170', 'income': 2044, 'Location': 'Bangalore', 'id': 'WIHQpire2T5EZnEoY6JI'}
# Missing fields in user: {'age': 100, 'Occupation': 'Unemployed', 'Name': 'User_306', 'income': 7037, 'Location': 'Mumbai', 'id': 'WIuQCVUfQoloYi5fVGnF'}
# Missing fields in user: {'age': 87, 'Occupation': 'Student', 'Name': 'User_6145', 'income': 1696, 'Location': 'Kolkata', 'id': 'WJucA27WFzxIwswMCOll'}
# Missing fields in user: {'age': 15, 'Occupation': 'Unemployed', 'Name': 'User_3293', 'income': 3643, 'Location': 'Delhi', 'id': 'WKJ6RuIxKQLwyqM6i7xY'}
# Missing fields in user: {'age': 26, 'Occupation': 'Worker', 'Name': 'User_4751', 'income': 6511, 'Location': 'Bangalore', 'id': 'WKM7JsC2LoV3uu0zs5lN'}
# Missing fields in user: {'age': 21, 'Occupation': 'Unemployed', 'Name': 'User_5363', 'income': 8199, 'Location': 'Kolkata', 'id': 'WKO6DZnlL9maBOtd0Iiu'}
# Missing fields in user: {'age': 3, 'Occupation': 'Student', 'Name': 'User_2802', 'income': 4206, 'Location': 'Bangalore', 'id': 'WKc1VtKXKpsCaH1Wa0iU'}
# Missing fields in user: {'age': 81, 'Occupation': 'Worker', 'Name': 'User_6333', 'income': 3493, 'Location': 'Bangalore', 'id': 'WL5lcpTmU2RvVAGbdoVF'}
# Missing fields in user: {'age': 78, 'Occupation': 'Unemployed', 'Name': 'User_5811', 'income': 9236, 'Location': 'Chennai', 'id': 'WMEh8aJ2kevhHC6ayVXF'}
# Missing fields in user: {'age': 72, 'Occupation': 'Unemployed', 'Name': 'User_9725', 'income': 6508, 'Location': 'Mumbai', 'id': 'WMMY7uZ9BSgowVD26N3C'}
# Missing fields in user: {'age': 7, 'Occupation': 'Student', 'Name': 'User_3086', 'income': 6111, 'Location': 'Delhi', 'id': 'WMuBOvAFQIyzMi9TiUxv'}
# Missing fields in user: {'age': 38, 'Occupation': 'Student', 'Name': 'User_6494', 'income': 2212, 'Location': 'Kolkata', 'id': 'WN2uAj8qrY5mWayoMTpQ'}
# Missing fields in user: {'age': 49, 'Occupation': 'Retired', 'Name': 'User_5820', 'income': 551, 'Location': 'Bangalore', 'id': 'WNFJakr75GfJ46pbyJ79'}
# Missing fields in user: {'age': 34, 'Occupation': 'Unemployed', 'Name': 'User_7435', 'income': 6466, 'Location': 'Delhi', 'id': 'WNkq0yT3q18ln8P6ktOC'}
# Missing fields in user: {'age': 14, 'Occupation': 'Worker', 'Name': 'User_4025', 'income': 7991, 'Location': 'Delhi', 'id': 'WO9P9v9DkhEpBFRImSZ7'}
# Missing fields in user: {'age': 77, 'Occupation': 'Unemployed', 'Name': 'User_7321', 'income': 1745, 'Location': 'Mumbai', 'id': 'WPBrLSqsaxCJat2qUmKy'}
# Missing fields in user: {'age': 18, 'Occupation': 'Unemployed', 'Name': 'User_3879', 'income': 4622, 'Location': 'Delhi', 'id': 'WPEbhe0iDngJgmW6cFLj'}
# Missing fields in user: {'age': 60, 'Occupation': 'Worker', 'Name': 'User_2274', 'income': 8527, 'Location': 'Chennai', 'id': 'WPph0Ak0YrutYklUXE96'}
# Missing fields in user: {'age': 38, 'Occupation': 'Unemployed', 'Name': 'User_2742', 'income': 8201, 'Location': 'Delhi', 'id': 'WQBcgJgLnX9CvPOaTPuF'}
# Missing fields in user: {'age': 4, 'Occupation': 'Student', 'Name': 'User_2813', 'income': 2195, 'Location': 'Bangalore', 'id': 'WQCYfxye2jpPdUO2bply'}
# Missing fields in user: {'age': 60, 'Occupation': 'Unemployed', 'Name': 'User_1291', 'income': 5064, 'Location': 'Mumbai', 'id': 'WQMyZE5yvzvNxAM1JZsn'}
# Missing fields in user: {'age': 85, 'Occupation': 'Student', 'Name': 'User_4489', 'income': 7995, 'Location': 'Mumbai', 'id': 'WQUTvHI0aD0xWx24FBqL'}
# Missing fields in user: {'age': 1, 'Occupation': 'Unemployed', 'Name': 'User_9996', 'income': 3048, 'Location': 'Bangalore', 'id': 'WQh644xynLOYqUAkiNBA'}
# Missing fields in user: {'age': 33, 'Occupation': 'Worker', 'Name': 'User_1759', 'income': 896, 'Location': 'Delhi', 'id': 'WQlndhHoFX3E0g0ZOkCm'}
# Missing fields in user: {'age': 86, 'Occupation': 'Student', 'Name': 'User_282', 'income': 6158, 'Location': 'Chennai', 'id': 'WRN0ju4wQ1Sad9WDYf0e'}
# Missing fields in user: {'age': 19, 'Occupation': 'Worker', 'Name': 'User_147', 'income': 8153, 'Location': 'Chennai', 'id': 'WRPfFSTszS2g2C56SI0k'}
# Missing fields in user: {'age': 16, 'Occupation': 'Worker', 'Name': 'User_2267', 'income': 5340, 'Location': 'Delhi', 'id': 'WRcToWzhg0PrwxC8sbdl'}
# Missing fields in user: {'age': 37, 'Occupation': 'Unemployed', 'Name': 'User_4860', 'income': 7475, 'Location': 'Kolkata', 'id': 'WRdCXSl9R16H9tfeeYFN'}
# Missing fields in user: {'age': 63, 'Occupation': 'Unemployed', 'Name': 'User_3205', 'income': 3014, 'Location': 'Chennai', 'id': 'WSVzwXocNpUufHwgGzl5'}
# Missing fields in user: {'age': 90, 'Occupation': 'Retired', 'Name': 'User_8263', 'income': 5805, 'Location': 'Kolkata', 'id': 'WT2r6GPmBZUitVwoAsyA'}
# Missing fields in user: {'age': 37, 'Occupation': 'Retired', 'Name': 'User_6454', 'income': 6226, 'Location': 'Chennai', 'id': 'WTQg9vqYCYY7c3g9Q7ut'}
# Missing fields in user: {'age': 52, 'Occupation': 'Unemployed', 'Name': 'User_87', 'income': 100, 'Location': 'Delhi', 'id': 'WTpWaIyHlqrQDJD05FzZ'}
# Missing fields in user: {'age': 76, 'Occupation': 'Unemployed', 'Name': 'User_3192', 'income': 5720, 'Location': 'Bangalore', 'id': 'WU5n84flcj2mdfsDr8iC'}
# Missing fields in user: {'age': 60, 'Occupation': 'Student', 'Name': 'User_416', 'income': 4922, 'Location': 'Bangalore', 'id': 'WVGQFIeML5IF03d1D68L'}
# Missing fields in user: {'age': 11, 'Occupation': 'Unemployed', 'Name': 'User_3116', 'income': 7130, 'Location': 'Mumbai', 'id': 'WVbQPkfbvBP1r5mWbejI'}
# Missing fields in user: {'age': 69, 'Occupation': 'Retired', 'Name': 'User_1157', 'income': 5687, 'Location': 'Mumbai', 'id': 'WViRDYPqBCDnrfMIykMc'}
# Missing fields in user: {'age': 29, 'Occupation': 'Student', 'Name': 'User_8051', 'income': 5557, 'Location': 'Kolkata', 'id': 'WWIgfvaIE8qae827VSRv'}
# Missing fields in user: {'age': 83, 'Occupation': 'Retired', 'Name': 'User_8454', 'income': 9776, 'Location': 'Delhi', 'id': 'WXEgGTivNXYBGfjZ4lMz'}
# Missing fields in user: {'age': 36, 'Occupation': 'Student', 'Name': 'User_8974', 'income': 1005, 'Location': 'Kolkata', 'id': 'WXIDtmsgnclQX7kf0l8v'}
# Missing fields in user: {'age': 27, 'Occupation': 'Student', 'Name': 'User_5728', 'income': 3675, 'Location': 'Kolkata', 'id': 'WXYwVBZVFxP2wcoGVK2b'}
# Missing fields in user: {'age': 43, 'Occupation': 'Unemployed', 'Name': 'User_2490', 'income': 5958, 'Location': 'Delhi', 'id': 'WXrtd2rs0BcwakkYq71d'}
# Missing fields in user: {'age': 36, 'Occupation': 'Retired', 'Name': 'User_490', 'income': 1259, 'Location': 'Bangalore', 'id': 'WY7olAxiRbCkughkbavb'}
# Missing fields in user: {'age': 62, 'Occupation': 'Student', 'Name': 'User_6522', 'income': 8224, 'Location': 'Kolkata', 'id': 'WYbGiGIqs9NFbc4HOj9D'}
# Missing fields in user: {'age': 75, 'Occupation': 'Student', 'Name': 'User_4453', 'income': 6001, 'Location': 'Kolkata', 'id': 'WYg6j03ES9VN3ryIZagn'}
# Missing fields in user: {'age': 92, 'Occupation': 'Student', 'Name': 'User_8253', 'income': 2006, 'Location': 'Kolkata', 'id': 'WYj5lcMI8cObMYn6o8cE'}
# Missing fields in user: {'age': 86, 'Occupation': 'Worker', 'Name': 'User_7586', 'income': 2381, 'Location': 'Kolkata', 'id': 'WYxl55DHGWGKSfkVg1ho'}
# Missing fields in user: {'age': 51, 'Occupation': 'Retired', 'Name': 'User_4394', 'income': 9238, 'Location': 'Delhi', 'id': 'WZ0YdKNxiEczEpsOpzrk'}
# Missing fields in user: {'age': 10, 'Occupation': 'Unemployed', 'Name': 'User_7038', 'income': 5445, 'Location': 'Bangalore', 'id': 'Wa5nA8DHKTHlASTgJV2A'}
# Missing fields in user: {'age': 87, 'Occupation': 'Student', 'Name': 'User_8488', 'income': 2177, 'Location': 'Kolkata', 'id': 'WaGBD05Q91izfmXhPphZ'}
# Missing fields in user: {'age': 57, 'Occupation': 'Student', 'Name': 'User_1656', 'income': 4638, 'Location': 'Kolkata', 'id': 'WaK0DbBvuFVOR4pxEcJD'}
# Missing fields in user: {'age': 63, 'Occupation': 'Worker', 'Name': 'User_4351', 'income': 6869, 'Location': 'Bangalore', 'id': 'WaKlpdeuwXjsTm7QObBd'}
# Missing fields in user: {'age': 81, 'Occupation': 'Student', 'Name': 'User_6465', 'income': 7822, 'Location': 'Kolkata', 'id': 'WamZXnTLCbu10s3vCJtA'}
# Missing fields in user: {'age': 97, 'Occupation': 'Unemployed', 'Name': 'User_3515', 'income': 1849, 'Location': 'Kolkata', 'id': 'WathBXwJ5we3IHtfWFWc'}
# Missing fields in user: {'age': 5, 'Occupation': 'Retired', 'Name': 'User_7980', 'income': 9277, 'Location': 'Bangalore', 'id': 'WbBZ6Z9nHy7KGpVWdMZN'}
# Missing fields in user: {'age': 3, 'Occupation': 'Retired', 'Name': 'User_3188', 'income': 3625, 'Location': 'Bangalore', 'id': 'WbERfNrtsUwecH2n0PUe'}
# Missing fields in user: {'age': 96, 'Occupation': 'Unemployed', 'Name': 'User_6286', 'income': 9044, 'Location': 'Kolkata', 'id': 'WbFrxFSjwnrN5jPHl3YJ'}
# Missing fields in user: {'age': 95, 'Occupation': 'Student', 'Name': 'User_7387', 'income': 7137, 'Location': 'Chennai', 'id': 'WcikR4S3WALEJJWV5kMD'}
# Missing fields in user: {'age': 8, 'Occupation': 'Worker', 'Name': 'User_1878', 'income': 5565, 'Location': 'Kolkata', 'id': 'WcjoJ5iGHewxqfr8eeIq'}
# Missing fields in user: {'age': 5, 'Occupation': 'Unemployed', 'Name': 'User_9268', 'income': 6649, 'Location': 'Delhi', 'id': 'WdCsu4NMlZ2gxqx9lTe9'}
# Missing fields in user: {'age': 77, 'Occupation': 'Unemployed', 'Name': 'User_2913', 'income': 6396, 'Location': 'Chennai', 'id': 'WdSh9OnGTllJFF0kwd58'}
# Missing fields in user: {'age': 64, 'Occupation': 'Unemployed', 'Name': 'User_7318', 'income': 5092, 'Location': 'Delhi', 'id': 'WdeCRy1sa1a9s3rLUM8V'}
# Missing fields in user: {'age': 96, 'Occupation': 'Unemployed', 'Name': 'User_9131', 'income': 6029, 'Location': 'Chennai', 'id': 'Wdqxkik5OrGzP6QqcPch'}
# Missing fields in user: {'age': 6, 'Occupation': 'Unemployed', 'Name': 'User_336', 'income': 1644, 'Location': 'Delhi', 'id': 'WdyHNqndKjTUrBuCBwlq'}
# Missing fields in user: {'age': 50, 'Occupation': 'Worker', 'Name': 'User_2254', 'income': 365, 'Location': 'Delhi', 'id': 'Wei1wv0EFgQP6AaWDKVd'}
# Missing fields in user: {'age': 21, 'Occupation': 'Retired', 'Name': 'User_4943', 'income': 7695, 'Location': 'Delhi', 'id': 'WezLjYuLyaaX44OXmjQw'}
# Missing fields in user: {'age': 4, 'Occupation': 'Student', 'Name': 'User_168', 'income': 1409, 'Location': 'Kolkata', 'id': 'WfXWl3W8lYbM2Y7G90aH'}
# Missing fields in user: {'age': 42, 'Occupation': 'Worker', 'Name': 'User_7977', 'income': 4962, 'Location': 'Kolkata', 'id': 'WfgFjl9UgmpAaWnyDZ2v'}
# Missing fields in user: {'age': 49, 'Occupation': 'Unemployed', 'Name': 'User_6132', 'income': 600, 'Location': 'Bangalore', 'id': 'WfhHlp8zalVrUwMRALkA'}
# Missing fields in user: {'age': 54, 'Occupation': 'Student', 'Name': 'User_2367', 'income': 5533, 'Location': 'Bangalore', 'id': 'WhDfWuCjzZbgn9a4kd4y'}
# Missing fields in user: {'age': 4, 'Occupation': 'Student', 'Name': 'User_853', 'income': 8080, 'Location': 'Kolkata', 'id': 'WkGNVYGGXoOKSwYqS3AN'}
# Missing fields in user: {'age': 99, 'Occupation': 'Student', 'Name': 'User_8614', 'income': 1524, 'Location': 'Mumbai', 'id': 'WkM7lyeeo9gsDvScx1vc'}
# Missing fields in user: {'age': 48, 'Occupation': 'Worker', 'Name': 'User_6440', 'income': 4288, 'Location': 'Bangalore', 'id': 'WliDONfgl8sGZZXS6xc9'}
# Missing fields in user: {'age': 76, 'Occupation': 'Unemployed', 'Name': 'User_8029', 'income': 5311, 'Location': 'Bangalore', 'id': 'WmKUt7m24MYoXAkuOQqw'}
# Missing fields in user: {'age': 30, 'Occupation': 'Worker', 'Name': 'User_6063', 'income': 7786, 'Location': 'Chennai', 'id': 'WmclLN9BAqY9aMxV31XI'}
# Missing fields in user: {'age': 40, 'Occupation': 'Worker', 'Name': 'User_8505', 'income': 8263, 'Location': 'Kolkata', 'id': 'Wn0fQf0R7jND6ewTyb4y'}
# Missing fields in user: {'age': 27, 'Occupation': 'Worker', 'Name': 'User_4899', 'income': 460, 'Location': 'Bangalore', 'id': 'WnbjmgROvDhilf7T0GXQ'}
# Missing fields in user: {'age': 80, 'Occupation': 'Retired', 'Name': 'User_7126', 'income': 1320, 'Location': 'Chennai', 'id': 'Wo7RwbBWlq7xrQRQ4XMk'}
# Missing fields in user: {'age': 97, 'Occupation': 'Worker', 'Name': 'User_2219', 'income': 8278, 'Location': 'Bangalore', 'id': 'WoD5pxZk7IHjBHWfYAjV'}
# Missing fields in user: {'age': 82, 'Occupation': 'Worker', 'Name': 'User_9521', 'income': 5698, 'Location': 'Chennai', 'id': 'Woy4vYOoJxSxklJoYoNG'}
# Missing fields in user: {'age': 40, 'Occupation': 'Retired', 'Name': 'User_8316', 'income': 3761, 'Location': 'Chennai', 'id': 'Wp39YvGcGuuPSWKMrZPQ'}
# Missing fields in user: {'age': 41, 'Occupation': 'Unemployed', 'Name': 'User_2929', 'income': 5225, 'Location': 'Kolkata', 'id': 'WpTU7BT8guyTF18zrgGZ'}
# Missing fields in user: {'age': 34, 'Occupation': 'Unemployed', 'Name': 'User_7094', 'income': 140, 'Location': 'Mumbai', 'id': 'WpVAqLwEFCG2mjAzA4JY'}
# Missing fields in user: {'age': 98, 'Occupation': 'Worker', 'Name': 'User_197', 'income': 3139, 'Location': 'Delhi', 'id': 'Wpq6K1B56Ms8c194cDtd'}
# Missing fields in user: {'age': 41, 'Occupation': 'Unemployed', 'Name': 'User_6563', 'income': 8585, 'Location': 'Kolkata', 'id': 'Wq3aJ3oO23zZkFMTiT1r'}
# Missing fields in user: {'age': 23, 'Occupation': 'Worker', 'Name': 'User_4572', 'income': 9128, 'Location': 'Delhi', 'id': 'WqGn0P0C1D0dzKjyKyy0'}
# Missing fields in user: {'age': 78, 'Occupation': 'Worker', 'Name': 'User_3682', 'income': 2278, 'Location': 'Bangalore', 'id': 'WqRLbO6MJuTVYARY6XxY'}
# Missing fields in user: {'age': 13, 'Occupation': 'Unemployed', 'Name': 'User_7847', 'income': 6230, 'Location': 'Bangalore', 'id': 'Wr1GMvAiOMkpToftF2eY'}
# Missing fields in user: {'age': 58, 'Occupation': 'Unemployed', 'Name': 'User_5577', 'income': 2969, 'Location': 'Delhi', 'id': 'WrDXWiJRcRykau5CGnMm'}
# Missing fields in user: {'age': 64, 'Occupation': 'Student', 'Name': 'User_9766', 'income': 5052, 'Location': 'Mumbai', 'id': 'Wrzmf56bDX9QCgLPj2bg'}
# Missing fields in user: {'age': 37, 'Occupation': 'Unemployed', 'Name': 'User_6575', 'income': 2080, 'Location': 'Delhi', 'id': 'Ws45xAd1KGYIUkfal0dg'}
# Missing fields in user: {'age': 35, 'Occupation': 'Unemployed', 'Name': 'User_4091', 'income': 8489, 'Location': 'Mumbai', 'id': 'WsALKybZJ7cWyp2paxGg'}
# Missing fields in user: {'age': 76, 'Occupation': 'Retired', 'Name': 'User_8387', 'income': 8433, 'Location': 'Kolkata', 'id': 'WsI5UbYY3HkNK6W3lLCb'}
# Missing fields in user: {'age': 44, 'Occupation': 'Student', 'Name': 'User_9372', 'income': 2030, 'Location': 'Chennai', 'id': 'WsN7WwVSgJBdqC0t1nkE'}
# Missing fields in user: {'age': 88, 'Occupation': 'Retired', 'Name': 'User_3997', 'income': 4699, 'Location': 'Bangalore', 'id': 'WsinvOvFVFxfrnrzxfWS'}
# Missing fields in user: {'age': 27, 'Occupation': 'Student', 'Name': 'User_6226', 'income': 2962, 'Location': 'Chennai', 'id': 'WtybBQHv7ygVheydDi1M'}
# Missing fields in user: {'age': 32, 'Occupation': 'Retired', 'Name': 'User_3719', 'income': 6351, 'Location': 'Delhi', 'id': 'WuP0nFt6g5U3eMWBTA58'}
# Missing fields in user: {'age': 41, 'Occupation': 'Unemployed', 'Name': 'User_3275', 'income': 3964, 'Location': 'Bangalore', 'id': 'WuXJq1eu43ppZbGZgVzM'}
# Missing fields in user: {'age': 53, 'Occupation': 'Student', 'Name': 'User_9657', 'income': 554, 'Location': 'Chennai', 'id': 'WuZL4NV41gj6CbrJIwnd'}
# Missing fields in user: {'age': 2, 'Occupation': 'Student', 'Name': 'User_4056', 'income': 4368, 'Location': 'Delhi', 'id': 'WvEAdKyxg2dnM4MwFzhA'}
# Missing fields in user: {'age': 76, 'Occupation': 'Worker', 'Name': 'User_1945', 'income': 867, 'Location': 'Kolkata', 'id': 'WvbCZ0Znzq4aK0VAerfA'}
# Missing fields in user: {'age': 78, 'Occupation': 'Unemployed', 'Name': 'User_6647', 'income': 2867, 'Location': 'Mumbai', 'id': 'WvzKG7lW6vfwJGQjYZlj'}
# Missing fields in user: {'age': 19, 'Occupation': 'Unemployed', 'Name': 'User_2476', 'income': 1783, 'Location': 'Bangalore', 'id': 'WwO0eX5WtDLzOc9bsooq'}
# Missing fields in user: {'age': 93, 'Occupation': 'Unemployed', 'Name': 'User_9282', 'income': 6958, 'Location': 'Delhi', 'id': 'WyH1MdtTHdyTAfNC3ZHZ'}
# Missing fields in user: {'age': 8, 'Occupation': 'Retired', 'Name': 'User_6695', 'income': 8594, 'Location': 'Delhi', 'id': 'WyNBYMgqL8qiXMP6TaAn'}
# Missing fields in user: {'age': 34, 'Occupation': 'Retired', 'Name': 'User_7410', 'income': 5636, 'Location': 'Kolkata', 'id': 'WyYbt7BtbwGMxBSeq9hY'}
# Missing fields in user: {'age': 98, 'Occupation': 'Unemployed', 'Name': 'User_2987', 'income': 5318, 'Location': 'Delhi', 'id': 'WylLVTqhUXLoKZGHqjBn'}
# Missing fields in user: {'age': 67, 'Occupation': 'Student', 'Name': 'User_916', 'income': 9606, 'Location': 'Kolkata', 'id': 'WyubeqktVsBahnnTHF4U'}
# Missing fields in user: {'age': 7, 'Occupation': 'Worker', 'Name': 'User_6739', 'income': 212, 'Location': 'Chennai', 'id': 'WzhhCenZ06Pa5UJ2lToj'}
# Missing fields in user: {'age': 99, 'Occupation': 'Retired', 'Name': 'User_6700', 'income': 91, 'Location': 'Kolkata', 'id': 'X0wQXYg2ERw4hy7ZkNR3'}
# Missing fields in user: {'age': 33, 'Occupation': 'Retired', 'Name': 'User_5303', 'income': 5423, 'Location': 'Chennai', 'id': 'X0x29kJg6Zfq5fD3UcY0'}
# Missing fields in user: {'age': 30, 'Occupation': 'Student', 'Name': 'User_7229', 'income': 5564, 'Location': 'Delhi', 'id': 'X22XU7XnOcwdm3Kj6LFr'}
# Missing fields in user: {'age': 70, 'Occupation': 'Unemployed', 'Name': 'User_849', 'income': 7526, 'Location': 'Mumbai', 'id': 'X26REGX31cXVEOOQslAo'}
# Missing fields in user: {'age': 16, 'Occupation': 'Student', 'Name': 'User_5478', 'income': 4472, 'Location': 'Delhi', 'id': 'X286FISxB77mOQJTf3Pu'}
# Missing fields in user: {'age': 16, 'Occupation': 'Student', 'Name': 'User_7301', 'income': 6195, 'Location': 'Bangalore', 'id': 'X2VH5xKXUc0fw5yHFvJC'}
# Missing fields in user: {'age': 70, 'Occupation': 'Unemployed', 'Name': 'User_4275', 'income': 7981, 'Location': 'Mumbai', 'id': 'X3Gn9PoQ1IsS6kWbg6Xb'}
# Missing fields in user: {'age': 0, 'Occupation': 'Retired', 'Name': 'User_4749', 'income': 1318, 'Location': 'Chennai', 'id': 'X3JXucGngcvBmHHywlWq'}
# Missing fields in user: {'age': 16, 'Occupation': 'Worker', 'Name': 'User_791', 'income': 223, 'Location': 'Chennai', 'id': 'X3T6vY0S4PuQIT7uxoda'}
# Missing fields in user: {'age': 73, 'Occupation': 'Retired', 'Name': 'User_2487', 'income': 9918, 'Location': 'Chennai', 'id': 'X4JD4w4TP2XkTVUx45TR'}
# Missing fields in user: {'age': 21, 'Occupation': 'Unemployed', 'Name': 'User_7941', 'income': 7821, 'Location': 'Bangalore', 'id': 'X4hDDNEirttmgJ93Nkph'}
# Missing fields in user: {'age': 99, 'Occupation': 'Student', 'Name': 'User_6423', 'income': 6436, 'Location': 'Chennai', 'id': 'X5Br1WntN1K5d3yOduyQ'}
# Missing fields in user: {'age': 35, 'Occupation': 'Retired', 'Name': 'User_2864', 'income': 2027, 'Location': 'Bangalore', 'id': 'X5LuZxPSjiILFvVE6t0q'}
# Missing fields in user: {'age': 41, 'Occupation': 'Retired', 'Name': 'User_2579', 'income': 9116, 'Location': 'Mumbai', 'id': 'X5WU9WS2frNK6Vayrvg6'}
# Missing fields in user: {'age': 70, 'Occupation': 'Worker', 'Name': 'User_1002', 'income': 6690, 'Location': 'Bangalore', 'id': 'X5aJUgBAd4NMO3ZoIp4R'}
# Missing fields in user: {'age': 21, 'Occupation': 'Worker', 'Name': 'User_1528', 'income': 3091, 'Location': 'Kolkata', 'id': 'X6Fg8VKbJvYETpVqPuPN'}
# Missing fields in user: {'age': 79, 'Occupation': 'Retired', 'Name': 'User_623', 'income': 4130, 'Location': 'Chennai', 'id': 'X6K0lYAkYCplVOr2bujz'}
# Missing fields in user: {'age': 45, 'Occupation': 'Worker', 'Name': 'User_5469', 'income': 8486, 'Location': 'Kolkata', 'id': 'X7Pb4vvx42VkvT8Bfcbd'}
# Missing fields in user: {'age': 91, 'Occupation': 'Unemployed', 'Name': 'User_3181', 'income': 1963, 'Location': 'Bangalore', 'id': 'X7Ufvl249gPzcT2yi2U9'}
# Missing fields in user: {'age': 54, 'Occupation': 'Unemployed', 'Name': 'User_6199', 'income': 6917, 'Location': 'Bangalore', 'id': 'X81uZ57a8QNuiIrIjUjq'}
# Missing fields in user: {'age': 83, 'Occupation': 'Unemployed', 'Name': 'User_9197', 'income': 2809, 'Location': 'Bangalore', 'id': 'X8HzcSoC5As1N251VMhl'}
# Missing fields in user: {'age': 41, 'Occupation': 'Retired', 'Name': 'User_6698', 'income': 4999, 'Location': 'Delhi', 'id': 'X9XEVakI1T9mCfLaA41I'}
# Missing fields in user: {'age': 17, 'Occupation': 'Student', 'Name': 'User_6536', 'income': 6605, 'Location': 'Delhi', 'id': 'XA9OeCATcjPcpZUukk8G'}
# Missing fields in user: {'age': 1, 'Occupation': 'Worker', 'Name': 'User_5657', 'income': 7753, 'Location': 'Mumbai', 'id': 'XAmFlFElp673j93XpPUd'}
# ...
# Missing fields in user: {'age': 66, 'Occupation': 'Retired', 'Name': 'User_2935', 'income': 5846, 'Location': 'Kolkata', 'id': 'zTyXULU6iJVsSBWdlQnD'}
# Missing fields in user: {'age': 23, 'Occupation': 'Unemployed', 'Name': 'User_5538', 'income': 1955, 'Location': 'Mumbai', 'id': 'zUG5L3qLf1mLIvs5Hw4V'}
# Missing fields in user: {'age': 5, 'Occupation': 'Student', 'Name': 'User_8676', 'income': 4982, 'Location': 'Mumbai', 'id': 'zUhPfMpoBnkybq3j5Zcu'}
# Missing fields in user: {'age': 36, 'Occupation': 'Student', 'Name': 'User_5071', 'income': 9778, 'Location': 'Mumbai', 'id': 'zVnaIsBdogWA7axrStf6'}
# Missing fields in user: {'age': 20, 'Occupation': 'Student', 'Name': 'User_8903', 'income': 127, 'Location': 'Kolkata', 'id': 'zVq6ZWgeZ7w62KPibGVn'}
# Missing fields in user: {'age': 3, 'Occupation': 'Unemployed', 'Name': 'User_7185', 'income': 7414, 'Location': 'Mumbai', 'id': 'zWj2kqMpToKHLUTp4fsI'}
# Missing fields in user: {'age': 41, 'Occupation': 'Retired', 'Name': 'User_1496', 'income': 7116, 'Location': 'Mumbai', 'id': 'zX0e04sH5CrkN45Qyqbb'}
# Missing fields in user: {'age': 84, 'Occupation': 'Retired', 'Name': 'User_7781', 'income': 9683, 'Location': 'Mumbai', 'id': 'zX4H4syjJfNR2j70yLGc'}
# Missing fields in user: {'age': 52, 'Occupation': 'Worker', 'Name': 'User_8365', 'income': 4483, 'Location': 'Mumbai', 'id': 'zXEdwmLfO07mF4p1SDsi'}
# Missing fields in user: {'age': 58, 'Occupation': 'Student', 'Name': 'User_925', 'income': 8563, 'Location': 'Mumbai', 'id': 'zXPJB0lTkDZrtlFNlQtT'}
# Missing fields in user: {'age': 38, 'Occupation': 'Student', 'Name': 'User_3347', 'income': 8277, 'Location': 'Bangalore', 'id': 'zXYuznz2tbtwXBDAOAVk'}
# Missing fields in user: {'age': 68, 'Occupation': 'Unemployed', 'Name': 'User_6923', 'income': 753, 'Location': 'Kolkata', 'id': 'zY83W7C7LOZyH10PNoQo'}
# Missing fields in user: {'age': 35, 'Occupation': 'Unemployed', 'Name': 'User_2486', 'income': 243, 'Location': 'Bangalore', 'id': 'zYbty56coP6XsWNq5zC9'}
# Missing fields in user: {'age': 28, 'Occupation': 'Worker', 'Name': 'User_9279', 'income': 1999, 'Location': 'Chennai', 'id': 'zYom5VtIfibzlDSAwEw0'}
# Missing fields in user: {'age': 76, 'Occupation': 'Unemployed', 'Name': 'User_9936', 'income': 4575, 'Location': 'Bangalore', 'id': 'zYsYQpmWbtXdvFCHqeYV'}
# Missing fields in user: {'age': 0, 'Occupation': 'Unemployed', 'Name': 'User_8526', 'income': 5142, 'Location': 'Kolkata', 'id': 'za0WNOAjOPKl1wHQ4hCf'}
# Missing fields in user: {'age': 0, 'Occupation': 'Retired', 'Name': 'User_9364', 'income': 254, 'Location': 'Delhi', 'id': 'za7YNKVgunvYNYF8jhj7'}
# Missing fields in user: {'age': 65, 'Occupation': 'Unemployed', 'Name': 'User_963', 'income': 8079, 'Location': 'Chennai', 'id': 'zaeIVvocVJtjM6FGQRhR'}
# Missing fields in user: {'age': 69, 'Occupation': 'Retired', 'Name': 'User_5482', 'income': 4798, 'Location': 'Delhi', 'id': 'zbGyv3xbuH0Zk5FAiB6D'}
# Missing fields in user: {'age': 18, 'Occupation': 'Unemployed', 'Name': 'User_30', 'income': 1505, 'Location': 'Mumbai', 'id': 'zbKS1L2yzjihV4uEfoAd'}
# Missing fields in user: {'age': 87, 'Occupation': 'Unemployed', 'Name': 'User_4070', 'income': 1016, 'Location': 'Chennai', 'id': 'zbsCglJVOu7RKJJmgaKi'}
# Missing fields in user: {'age': 8, 'Occupation': 'Retired', 'Name': 'User_6024', 'income': 2399, 'Location': 'Mumbai', 'id': 'zbwlUnQjTKHzOT7Qlu7u'}
# Missing fields in user: {'age': 97, 'Occupation': 'Unemployed', 'Name': 'User_1479', 'income': 7695, 'Location': 'Mumbai', 'id': 'zc1jvD0Ps3Vqf5zS7zHM'}
# Missing fields in user: {'age': 85, 'Occupation': 'Worker', 'Name': 'User_2834', 'income': 8639, 'Location': 'Bangalore', 'id': 'zcI4YHHmYNsvyLb1aYcz'}
# Missing fields in user: {'age': 51, 'Occupation': 'Student', 'Name': 'User_4262', 'income': 5938, 'Location': 'Kolkata', 'id': 'zcxaWuLpLbtLT65k2qVu'}
# Missing fields in user: {'age': 6, 'Occupation': 'Worker', 'Name': 'User_4399', 'income': 1785, 'Location': 'Chennai', 'id': 'zd5qyQJP3Siu7jdwrkfe'}
# Missing fields in user: {'age': 12, 'Occupation': 'Student', 'Name': 'User_6477', 'income': 7929, 'Location': 'Bangalore', 'id': 'zdehv7Oc5u9z4XzrF7p4'}
# Missing fields in user: {'age': 51, 'Occupation': 'Worker', 'Name': 'User_1020', 'income': 6687, 'Location': 'Chennai', 'id': 'zeVuFCaswZuJlbR3RpHJ'}
# Missing fields in user: {'age': 38, 'Occupation': 'Worker', 'Name': 'User_2818', 'income': 9497, 'Location': 'Bangalore', 'id': 'zeX4EvSQSD8fMaZZMqYj'}
# Missing fields in user: {'age': 67, 'Occupation': 'Retired', 'Name': 'User_1920', 'income': 4241, 'Location': 'Kolkata', 'id': 'zfP6Lm53ZZwHAtfgtOrT'}
# Missing fields in user: {'age': 94, 'Occupation': 'Retired', 'Name': 'User_8609', 'income': 619, 'Location': 'Delhi', 'id': 'zffYGA8LULE7555UZqxQ'}
# Missing fields in user: {'age': 71, 'Occupation': 'Worker', 'Name': 'User_9877', 'income': 6353, 'Location': 'Chennai', 'id': 'zgBo4M312pfCcutyXPsN'}
# Missing fields in user: {'age': 40, 'Occupation': 'Retired', 'Name': 'User_9911', 'income': 1511, 'Location': 'Mumbai', 'id': 'zgiDwfotH3cjrFbEeUnj'}
# Missing fields in user: {'age': 93, 'Occupation': 'Retired', 'Name': 'User_7947', 'income': 1406, 'Location': 'Chennai', 'id': 'zgrgV9QEp7rJCpimIbyG'}
# Missing fields in user: {'age': 47, 'Occupation': 'Worker', 'Name': 'User_9647', 'income': 6684, 'Location': 'Chennai', 'id': 'zgwa2XDGcAqXVG4IN9Z6'}
# Missing fields in user: {'age': 78, 'Occupation': 'Unemployed', 'Name': 'User_1663', 'income': 6603, 'Location': 'Chennai', 'id': 'zgwhRsxJJVncqm6fLcf2'}
# Missing fields in user: {'age': 63, 'Occupation': 'Student', 'Name': 'User_112', 'income': 3634, 'Location': 'Kolkata', 'id': 'zhgosAkX0uVapcJUkbLv'}
# Missing fields in user: {'age': 84, 'Occupation': 'Retired', 'Name': 'User_2360', 'income': 168, 'Location': 'Delhi', 'id': 'zi4a7q163HGx44LLFQth'}
# Missing fields in user: {'age': 82, 'Occupation': 'Retired', 'Name': 'User_6288', 'income': 5766, 'Location': 'Bangalore', 'id': 'ziYfdVWOQ0RaNy2FMeY0'}
# Missing fields in user: {'age': 75, 'Occupation': 'Student', 'Name': 'User_3606', 'income': 7401, 'Location': 'Mumbai', 'id': 'zinopsg2mS2GbMtclsk0'}
# Missing fields in user: {'age': 43, 'Occupation': 'Unemployed', 'Name': 'User_8973', 'income': 5318, 'Location': 'Chennai', 'id': 'zjHmtCnpLeqSRzxBtfmD'}
# Missing fields in user: {'age': 2, 'Occupation': 'Retired', 'Name': 'User_3406', 'income': 8185, 'Location': 'Kolkata', 'id': 'zk7KjBH4cuyjhowKcv9S'}
# Missing fields in user: {'age': 73, 'Occupation': 'Unemployed', 'Name': 'User_6453', 'income': 3804, 'Location': 'Delhi', 'id': 'zkAmqFl3PtutnPaXWfGU'}
# Missing fields in user: {'age': 18, 'Occupation': 'Worker', 'Name': 'User_7466', 'income': 2328, 'Location': 'Delhi', 'id': 'zkIaa6PNuifnxtsD2Wbd'}
# Missing fields in user: {'age': 46, 'Occupation': 'Retired', 'Name': 'User_226', 'income': 6308, 'Location': 'Chennai', 'id': 'zkn8Il5bNPTCXEPo4cIQ'}
# Missing fields in user: {'age': 25, 'Occupation': 'Retired', 'Name': 'User_6866', 'income': 72, 'Location': 'Mumbai', 'id': 'zksMi2kfJvPEYsIgG3sL'}
# Missing fields in user: {'age': 55, 'Occupation': 'Unemployed', 'Name': 'User_4133', 'income': 5284, 'Location': 'Kolkata', 'id': 'zlIY71bWjfoi9zknftyi'}
# Missing fields in user: {'age': 20, 'Occupation': 'Unemployed', 'Name': 'User_4000', 'income': 4374, 'Location': 'Mumbai', 'id': 'zlyU13veRsoi75H9Bv28'}
# Missing fields in user: {'age': 36, 'Occupation': 'Student', 'Name': 'User_4395', 'income': 3211, 'Location': 'Chennai', 'id': 'zmDHlb87A3xGMx7w5sy6'}
# Missing fields in user: {'age': 69, 'Occupation': 'Student', 'Name': 'User_1409', 'income': 454, 'Location': 'Kolkata', 'id': 'zn1qqHHmTx8GPBowD06A'}
# Missing fields in user: {'age': 55, 'Occupation': 'Worker', 'Name': 'User_9517', 'income': 1019, 'Location': 'Bangalore', 'id': 'zoXFLiXjv8Uuqb56fczq'}
# Missing fields in user: {'age': 2, 'Occupation': 'Student', 'Name': 'User_1610', 'income': 2920, 'Location': 'Delhi', 'id': 'zoXMZoGCO9GY7eJIKtGj'}
# Missing fields in user: {'age': 58, 'Occupation': 'Student', 'Name': 'User_1730', 'income': 6858, 'Location': 'Chennai', 'id': 'zos3BJZZ5JF7GjIQahLg'}
# Missing fields in user: {'age': 52, 'Occupation': 'Worker', 'Name': 'User_2323', 'income': 1827, 'Location': 'Kolkata', 'id': 'zounTgAYtcB53r1xn5e8'}
# Missing fields in user: {'age': 53, 'Occupation': 'Worker', 'Name': 'User_8086', 'income': 1352, 'Location': 'Bangalore', 'id': 'zpEC27g9dxG7pYePmFQj'}
# Missing fields in user: {'age': 94, 'Occupation': 'Retired', 'Name': 'User_1657', 'income': 1166, 'Location': 'Bangalore', 'id': 'zphiz8w7VgYzJyi8cwpn'}
# Missing fields in user: {'age': 45, 'Occupation': 'Student', 'Name': 'User_7495', 'income': 4764, 'Location': 'Mumbai', 'id': 'zqFMFrqxxG95pK5TXMzt'}
# Missing fields in user: {'age': 59, 'Occupation': 'Unemployed', 'Name': 'User_7202', 'income': 9967, 'Location': 'Mumbai', 'id': 'zqTMBiqD1VbpbOdO5Hfc'}
# Missing fields in user: {'age': 62, 'Occupation': 'Unemployed', 'Name': 'User_8603', 'income': 6684, 'Location': 'Delhi', 'id': 'zqcdG3mMU6K2hoVDoy0U'}
# Missing fields in user: {'age': 79, 'Occupation': 'Retired', 'Name': 'User_4243', 'income': 3460, 'Location': 'Mumbai', 'id': 'zrHywluLQZazw8qZFiWg'}
# Missing fields in user: {'age': 31, 'Occupation': 'Student', 'Name': 'User_6463', 'income': 9051, 'Location': 'Bangalore', 'id': 'zraayIGbQWqiIAWXCYIQ'}
# Missing fields in user: {'age': 1, 'Occupation': 'Student', 'Name': 'User_3489', 'income': 5088, 'Location': 'Kolkata', 'id': 'zrhSZUzp3nPNEKwYOkU6'}
# Missing fields in user: {'age': 38, 'Occupation': 'Unemployed', 'Name': 'User_4084', 'income': 2207, 'Location': 'Bangalore', 'id': 'zrmEDVxHvGoxNtlyf7dQ'}
# Missing fields in user: {'age': 80, 'Occupation': 'Student', 'Name': 'User_2521', 'income': 6693, 'Location': 'Kolkata', 'id': 'zrtXgZKfMbU5wl5UnAxD'}
# Missing fields in user: {'age': 69, 'Occupation': 'Worker', 'Name': 'User_555', 'income': 1341, 'Location': 'Chennai', 'id': 'zsIQoxoUiVGTCPaSpw10'}
# Missing fields in user: {'age': 31, 'Occupation': 'Student', 'Name': 'User_2123', 'income': 4905, 'Location': 'Delhi', 'id': 'zssdZsKDGXDOFAJdW030'}
# Missing fields in user: {'age': 66, 'Occupation': 'Student', 'Name': 'User_6338', 'income': 1838, 'Location': 'Mumbai', 'id': 'ztIz0KwSr7yVHBBIXPV3'}
# Missing fields in user: {'age': 75, 'Occupation': 'Retired', 'Name': 'User_6965', 'income': 6612, 'Location': 'Kolkata', 'id': 'ztXOwLnEiRVWoqFFZzZe'}
# Missing fields in user: {'age': 31, 'Occupation': 'Retired', 'Name': 'User_7536', 'income': 2974, 'Location': 'Chennai', 'id': 'ztq6cKomooT6HxWadf0Q'}
# Missing fields in user: {'age': 34, 'Occupation': 'Unemployed', 'Name': 'User_1025', 'income': 8618, 'Location': 'Chennai', 'id': 'zu5sWFXBVaKOT6v8TmZg'}
# Missing fields in user: {'age': 23, 'Occupation': 'Worker', 'Name': 'User_3812', 'income': 3271, 'Location': 'Kolkata', 'id': 'zuOSqzXe5nhF4ulEfGIq'}
# Missing fields in user: {'age': 45, 'Occupation': 'Worker', 'Name': 'User_7003', 'income': 7532, 'Location': 'Bangalore', 'id': 'zubcenWByfk8o6RUQ8Xi'}
# Missing fields in user: {'age': 51, 'Occupation': 'Unemployed', 'Name': 'User_5704', 'income': 7988, 'Location': 'Delhi', 'id': 'zvP1CGbKe8E0ihgASY2C'}
# Missing fields in user: {'age': 32, 'Occupation': 'Student', 'Name': 'User_5860', 'income': 9825, 'Location': 'Chennai', 'id': 'zvl1hHoDyPKcWJ9wI6dI'}
# Missing fields in user: {'age': 3, 'Occupation': 'Worker', 'Name': 'User_5799', 'income': 2867, 'Location': 'Chennai', 'id': 'zwhO2afdOP3NTE6Hnuev'}
# Missing fields in user: {'age': 11, 'Occupation': 'Student', 'Name': 'User_6186', 'income': 2413, 'Location': 'Kolkata', 'id': 'zwi053hKOtXYZnP5Ve5i'}
# Missing fields in user: {'age': 80, 'Occupation': 'Worker', 'Name': 'User_1817', 'income': 2438, 'Location': 'Mumbai', 'id': 'zwlvd8XCRlzzWZIKDys2'}
# Missing fields in user: {'age': 85, 'Occupation': 'Retired', 'Name': 'User_4805', 'income': 1040, 'Location': 'Mumbai', 'id': 'zwmtZ6xckt5YlGT2srjj'}
# Missing fields in user: {'age': 50, 'Occupation': 'Student', 'Name': 'User_4815', 'income': 7769, 'Location': 'Chennai', 'id': 'zx51t64hupUrgyGFZOkp'}
# Missing fields in user: {'age': 32, 'Occupation': 'Retired', 'Name': 'User_5646', 'income': 7495, 'Location': 'Bangalore', 'id': 'zxBT0psyKUUlBH9EDK4C'}
# Missing fields in user: {'age': 77, 'Occupation': 'Student', 'Name': 'User_8892', 'income': 2416, 'Location': 'Kolkata', 'id': 'zxGBktwNsvXqV63SsQuY'}
# Missing fields in user: {'age': 56, 'Occupation': 'Student', 'Name': 'User_1800', 'income': 8167, 'Location': 'Chennai', 'id': 'zxTh8e6fPXgbQeXiu0yb'}
# Missing fields in user: {'age': 1, 'Occupation': 'Student', 'Name': 'User_6352', 'income': 1801, 'Location': 'Bangalore', 'id': 'zxxKip1KE0nsP8r4ymZ9'}
# Missing fields in user: {'age': 75, 'Occupation': 'Student', 'Name': 'User_3175', 'income': 8980, 'Location': 'Kolkata', 'id': 'zy9R0e3j4a9XahzqzZ7V'}
# Missing fields in user: {'age': 40, 'Occupation': 'Retired', 'Name': 'User_2171', 'income': 5097, 'Location': 'Mumbai', 'id': 'zze0Kr9NwmV2j3fsdqdd'}
# Preprocessed 0 valid user profiles.
# Missing fields in scheme: {'Scheme Name': 'National Scheme for Incentive to Girls for Secondary Education', 'Benefits': 'Financial incentive for girls in secondary schools.', 'eligibility': {'income': 10000, 'occupation': 'Student'}, 'Requirements': 'School certificate, Income proof', 'Age Range': '0-18', 'Purpose': 'Secondary Education', 'id': '2OKbKgjgFF5HVnX8cxcO'}
# Missing fields in scheme: {'Scheme Name': 'Indira Gandhi National Old Age Pension Scheme', 'Benefits': 'Provides pension to senior citizens.', 'eligibility': {'income': 10000, 'occupation': 'Retired'}, 'Requirements': 'Age proof, Income proof', 'Age Range': '55+', 'Purpose': 'Pension', 'id': 'DXdINlG6LT0j541rMpsp'}
# Missing fields in scheme: {'Scheme Name': 'Beti Bachao Beti Padhao', 'Benefits': 'Promotes education for girls, provides financial aid.', 'eligibility': {'income': 10000, 'occupation': 'Student'}, 'Requirements': 'Birth certificate, Income proof', 'Age Range': '0-18', 'Purpose': 'Education and Empowerment', 'id': 'DZWalCW0RO1IfNGhjKfw'}
# Missing fields in scheme: {'Scheme Name': 'Mahila E-Haat', 'Benefits': 'Online marketing platform for women entrepreneurs.', 'eligibility': {'income': 10000, 'occupation': 'Worker'}, 'Requirements': 'ID proof, Income proof', 'Age Range': '18-55', 'Purpose': 'Employment', 'id': 'Stgd4jnokP1QZvkdFb8P'}
# Missing fields in scheme: {'Scheme Name': 'Varishta Pension Bima Yojana', 'Benefits': 'Provides assured pension to senior citizens.', 'eligibility': {'income': 10000, 'occupation': 'Retired'}, 'Requirements': 'ID proof, Income proof', 'Age Range': '55+', 'Purpose': 'Pension', 'id': 'T1IpK5nSySBUGEkhXAV1'}
# Missing fields in scheme: {'Scheme Name': 'Mid-Day Meal Scheme', 'Benefits': 'Provides free meals in schools.', 'eligibility': {'income': 10000, 'occupation': 'Student'}, 'Requirements': 'School enrollment proof', 'Age Range': '0-18', 'Purpose': 'Nutrition', 'id': 'ZBZq8UaYr9LOsk4jjhI2'}
# Missing fields in scheme: {'Scheme Name': 'Rashtriya Vayoshri Yojana', 'Benefits': 'Free physical aids and assisted-living devices for senior citizens.', 'eligibility': {'income': 10000, 'occupation': 'Retired'}, 'Requirements': 'Age proof, Income proof', 'Age Range': '55+', 'Purpose': 'Healthcare', 'id': 'bHx45ixDTXT1qC41Iiwb'}
# Missing fields in scheme: {'Scheme Name': 'Pradhan Mantri Matru Vandana Yojana', 'Benefits': 'Cash incentive for pregnant women and lactating mothers.', 'eligibility': {'income': 10000, 'occupation': 'Worker'}, 'Requirements': 'Pregnancy certificate, Income proof', 'Age Range': '18-55', 'Purpose': 'Maternal Health', 'id': 'eE7EhkkbULyDjMpwuDVh'}
# Missing fields in scheme: {'Scheme Name': 'Support to Training and Employment Programme for Women (STEP)', 'Benefits': 'Skill development for women in various trades.', 'eligibility': {'income': 10000, 'occupation': 'Worker'}, 'Requirements': 'ID proof, Income proof', 'Age Range': '18-55', 'Purpose': 'Skill Development', 'id': 'uXTPXqQkI7aKOQOce5pI'}
# Preprocessed 0 valid schemes.
# Valid Users: 0
# Valid Schemes: 0

# %%
print("Raw Users Data:")
print(users_data[:5])  # Print the first 5 user records

print("Raw Schemes Data:")
print(schemes_data[:5])  # Print the first 5 scheme records
# Out:
# Raw Users Data:
# [{'age': 15, 'Occupation': 'Unemployed', 'Name': 'User_3556', 'income': 5287, 'Location': 'Chennai', 'id': '00EPfRXylUvn6nxTXkaZ'}, {'age': 5, 'Occupation': 'Retired', 'Name': 'User_2525', 'income': 7161, 'Location': 'Bangalore', 'id': '00w3gORwHXNQqQldz5CR'}, {'age': 81, 'Occupation': 'Retired', 'Name': 'User_3584', 'income': 1181, 'Location': 'Kolkata', 'id': '02LwRORnXdE2OhHCrm25'}, {'age': 99, 'Occupation': 'Worker', 'Name': 'User_5018', 'income': 3903, 'Location': 'Bangalore', 'id': '02sC5s1KcYQKATH97hOR'}, {'age': 76, 'Occupation': 'Student', 'Name': 'User_3955', 'income': 762, 'Location': 'Delhi', 'id': '03SrcDBSH7mh02X6gcDE'}]
# Raw Schemes Data:
# [{'Scheme Name': 'National Scheme for Incentive to Girls for Secondary Education', 'Benefits': 'Financial incentive for girls in secondary schools.', 'eligibility': {'income': 10000, 'occupation': 'Student'}, 'Requirements': 'School certificate, Income proof', 'Age Range': '0-18', 'Purpose': 'Secondary Education', 'id': '2OKbKgjgFF5HVnX8cxcO'}, {'Scheme Name': 'Indira Gandhi National Old Age Pension Scheme', 'Benefits': 'Provides pension to senior citizens.', 'eligibility': {'income': 10000, 'occupation': 'Retired'}, 'Requirements': 'Age proof, Income proof', 'Age Range': '55+', 'Purpose': 'Pension', 'id': 'DXdINlG6LT0j541rMpsp'}, {'Scheme Name': 'Beti Bachao Beti Padhao', 'Benefits': 'Promotes education for girls, provides financial aid.', 'eligibility': {'income': 10000, 'occupation': 'Student'}, 'Requirements': 'Birth certificate, Income proof', 'Age Range': '0-18', 'Purpose': 'Education and Empowerment', 'id': 'DZWalCW0RO1IfNGhjKfw'}, {'Scheme Name': 'Mahila E-Haat', 'Benefits': 'Online marketing platform for women entrepreneurs.', 'eligibility': {'income': 10000, 'occupation': 'Worker'}, 'Requirements': 'ID proof, Income proof', 'Age Range': '18-55', 'Purpose': 'Employment', 'id': 'Stgd4jnokP1QZvkdFb8P'}, {'Scheme Name': 'Varishta Pension Bima Yojana', 'Benefits': 'Provides assured pension to senior citizens.', 'eligibility': {'income': 10000, 'occupation': 'Retired'}, 'Requirements': 'ID proof, Income proof', 'Age Range': '55+', 'Purpose': 'Pension', 'id': 'T1IpK5nSySBUGEkhXAV1'}]

# %%
def preprocess_users(users_data):
    """Preprocess user profiles to ensure required fields are present."""
    valid_users = []
    for user in users_data:
        # Normalize field names
        user["Age"] = user.get("age", 0)
        user["Income"] = user.get("income", 0)
        user["Occupation"] = user.get("Occupation", "Unknown")

        # Validate required fields
        if isinstance(user["Age"], (int, float)) and user["Age"] >= 0 and user["Income"] <= 10000:
            valid_users.append(user)
        else:
            print(f"Invalid user profile: {user}")
    print(f"Preprocessed {len(valid_users)} valid user profiles.")
    return valid_users


def preprocess_schemes(schemes_data):
    """Preprocess scheme data to ensure required fields are present and parse eligibility."""
    valid_schemes = []
    for scheme in schemes_data:
        # Normalize field names
        scheme["Eligibility"] = scheme.get("eligibility", {})

        # Validate required fields
        if all(key in scheme for key in ["Age Range", "Eligibility", "Scheme Name"]):
            valid_schemes.append(scheme)
        else:
            print(f"Invalid scheme data: {scheme}")
    print(f"Preprocessed {len(valid_schemes)} valid schemes.")
    return valid_schemes


# Preprocess data
preprocessed_users = preprocess_users(users_data)
preprocessed_schemes = preprocess_schemes(schemes_data)

# Display counts for verification
print(f"Valid Users: {len(preprocessed_users)}")
print(f"Valid Schemes: {len(preprocessed_schemes)}")
# Out:
# Preprocessed 10000 valid user profiles.
# Preprocessed 9 valid schemes.
# Valid Users: 10000
# Valid Schemes: 9

# %%
def filter_schemes_by_age(users, schemes):
    """Filter schemes for each user based on their age group."""
    age_groups = {
        "0-18": lambda age: 0 <= age <= 18,
        "18-55": lambda age: 18 < age <= 55,
        "55+": lambda age: age > 55,
    }

    user_filtered_schemes = []

    for user in users:
        user_age = user["Age"]
        user_id = user["id"]
        relevant_schemes = []

        # Match schemes based on age group
        for scheme in schemes:
            age_range = scheme["Age Range"]
            if age_range in age_groups and age_groups[age_range](user_age):
                relevant_schemes.append(scheme)

        user_filtered_schemes.append({
            "user_id": user_id,
            "user_age": user_age,
            "relevant_schemes": relevant_schemes
        })

    print(f"Filtered schemes for {len(user_filtered_schemes)} users.")
    return user_filtered_schemes


# Filter schemes by age group
filtered_data = filter_schemes_by_age(preprocessed_users, preprocessed_schemes)

# Example output for a single user
print(f"Example filtered data for User 1: {filtered_data[0]}")
# Out:
# Filtered schemes for 10000 users.
# Example filtered data for User 1: {'user_id': '00EPfRXylUvn6nxTXkaZ', 'user_age': 15, 'relevant_schemes': [{'Scheme Name': 'National Scheme for Incentive to Girls for Secondary Education', 'Benefits': 'Financial incentive for girls in secondary schools.', 'eligibility': {'income': 10000, 'occupation': 'Student'}, 'Requirements': 'School certificate, Income proof', 'Age Range': '0-18', 'Purpose': 'Secondary Education', 'id': '2OKbKgjgFF5HVnX8cxcO', 'Eligibility': {'income': 10000, 'occupation': 'Student'}}, {'Scheme Name': 'Beti Bachao Beti Padhao', 'Benefits': 'Promotes education for girls, provides financial aid.', 'eligibility': {'income': 10000, 'occupation': 'Student'}, 'Requirements': 'Birth certificate, Income proof', 'Age Range': '0-18', 'Purpose': 'Education and Empowerment', 'id': 'DZWalCW0RO1IfNGhjKfw', 'Eligibility': {'income': 10000, 'occupation': 'Student'}}, {'Scheme Name': 'Mid-Day Meal Scheme', 'Benefits': 'Provides free meals in schools.', 'eligibility': {'income': 10000, 'occupation': 'Student'}, 'Requirements': 'School enrollment proof', 'Age Range': '0-18', 'Purpose': 'Nutrition', 'id': 'ZBZq8UaYr9LOsk4jjhI2', 'Eligibility': {'income': 10000, 'occupation': 'Student'}}]}

# %%
def calculate_match_rate(user, schemes):
    """Calculate match rate for the user against relevant schemes."""
    match_results = []

    for scheme in schemes:
        match_rate = 50  # Base score for age group match

        # Occupation match (30%)
        if scheme["Eligibility"].get("occupation") == user["Occupation"]:
            match_rate += 30

        # Income eligibility (20%)
        if user["Income"] <= scheme["Eligibility"].get("income", 0):
            match_rate += 20

        match_results.append({
            "Scheme Name": scheme["Scheme Name"],
            "Match Rate (%)": match_rate,
            "Benefits": scheme["Benefits"],
            "Requirements": scheme["Requirements"]
        })

    return match_results


def apply_eligibility_matching(filtered_data):
    """Apply eligibility matching to all users."""
    matched_results = []

    for entry in filtered_data:
        user_id = entry["user_id"]
        user_age = entry["user_age"]
        user_relevant_schemes = entry["relevant_schemes"]

        # Calculate match rates
        user_matches = calculate_match_rate(
            {"Age": user_age, "Income": preprocessed_users[0]["Income"], "Occupation": preprocessed_users[0]["Occupation"]},
            user_relevant_schemes
        )

        matched_results.append({
            "user_id": user_id,
            "matches": user_matches
        })

    print(f"Applied eligibility matching for {len(matched_results)} users.")
    return matched_results


# Apply eligibility matching
matched_data = apply_eligibility_matching(filtered_data)

# Example output for a single user
print(f"Example matched data for User 1: {matched_data[0]}")
# Out:
# Applied eligibility matching for 10000 users.
# Example matched data for User 1: {'user_id': '00EPfRXylUvn6nxTXkaZ', 'matches': [{'Scheme Name': 'National Scheme for Incentive to Girls for Secondary Education', 'Match Rate (%)': 70, 'Benefits': 'Financial incentive for girls in secondary schools.', 'Requirements': 'School certificate, Income proof'}, {'Scheme Name': 'Beti Bachao Beti Padhao', 'Match Rate (%)': 70, 'Benefits': 'Promotes education for girls, provides financial aid.', 'Requirements': 'Birth certificate, Income proof'}, {'Scheme Name': 'Mid-Day Meal Scheme', 'Match Rate (%)': 70, 'Benefits': 'Provides free meals in schools.', 'Requirements': 'School enrollment proof'}]}

# %%
def save_to_firestore(matched_data):
    """Save matched results to Firestore."""
    user_matches_ref = db.collection("user_matches")  # Firestore collection name: user_matches

    for user_data in matched_data:
        user_id = user_data["user_id"]
        matches = user_data["matches"]

        try:
            # Add or update user matches in Firestore
            user_matches_ref.document(user_id).set({
                "user_id": user_id,
                "matches": matches
            })
        except Exception as e:
            print(f"Error saving data for user {user_id}: {e}")

    print("Matched data successfully saved to Firestore.")


# Save matched data to Firestore
save_to_firestore(matched_data)
# Out:
# Matched data successfully saved to Firestore.
